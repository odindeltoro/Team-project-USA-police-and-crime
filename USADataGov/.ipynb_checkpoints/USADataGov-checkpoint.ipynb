# %% [markdown]
# # ETL USA Data Gov API

# %% [markdown]
# This is a public API with access to USA Data Government data set of FBI Crime Data [FBI API](https://api.data.gov/docs/fbi/).

# %% [markdown]
# **Endpoints pertaining to CDE Related Lookup Value data:**
#
# * Returns List of States utilized by CDE Endpoint
#
# * Returns List of Regions utilized by CDE Endpoint
#
# * Returns List of Agencies utilized by CDE Endpoint
#
# **Endpoints pertaining to UCR Estimated Crime Data:**
#
# * National level UCR Estimated Crime Data Endpoint 1985-2018
#
# * State level UCR Estimated Crime Data Endpoint 1985-2018
#
# **Endpoints pertaining to Arrest Demographic data:**
#
# * National level Arrest Demographic Count Endpoint 1985-2018
#
# * State level Arrest Demographic Count Endpoint 1985-2018
#
# **Endpoints pertaining to UCR Police Employment data:**
#
# * National level UCR Police Employment Endpoint 1985-2018
#
# * State level UCR Police Employment Endpoint 1985-2018

# %% [markdown]
# Data has supported formats CSV or JSON. The call will be for JSON format.

# %% [markdown]
# ### Extract data from source

# %%
# Import dependencies
import requests
import json

# %%
# Import API key
from api_keys import datagov_key
# URLs
FBIurl = 'https://api.usa.gov/crime/fbi/sapi/'

# %%
# Regions catalogue data
regions = f"{FBIurl}api/regions"
# Url
regionsUrl = f"{regions}?api_key={datagov_key}"
# Retrieve data and convert to json
regionsCatalogue = requests.get(regionsUrl).json()
# Out:
# {'results': [{'region_code': 0,
#    'region_name': 'U.S. Territories',
#    'region_desc': 'U.S. Territories'},
#   {'region_code': 1, 'region_name': 'Northeast', 'region_desc': 'Region I'},
#   {'region_code': 2, 'region_name': 'Midwest', 'region_desc': 'Region II'},
#   {'region_code': 3, 'region_name': 'South', 'region_desc': 'Region III'},
#   {'region_code': 4, 'region_name': 'West', 'region_desc': 'Region IV'},
#   {'region_code': 99, 'region_name': 'Other', 'region_desc': 'Other'}],
#  'pagination': {'count': 6, 'page': 0, 'pages': 1, 'per_page': 20}}

# %%
# State catalogue data
states = f"{FBIurl}api/states"
# Url
statesUrl0 = f"{states}?api_key={datagov_key}&page=0"
statesUrl1 = f"{states}?api_key={datagov_key}&page=1"
statesUrl2 = f"{states}?api_key={datagov_key}&page=2"
statesUrl3 = f"{states}?api_key={datagov_key}&page=3"
# Retrieve data and convert to json
statesCatalogue0 = requests.get(statesUrl0).json()
statesCatalogue1 = requests.get(statesUrl1).json()
statesCatalogue2 = requests.get(statesUrl2).json()
statesCatalogue3 = requests.get(statesUrl3).json()
# Out:
# {'results': [{'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'region_code': 4,
#    'state_fips_code': 2},
#   {'state_id': 2,
#    'state_name': 'Alabama',
#    'state_abbr': 'AL',
#    'region_code': 3,
#    'state_fips_code': 1},
#   {'state_id': 3,
#    'state_name': 'Arkansas',
#    'state_abbr': 'AR',
#    'region_code': 3,
#    'state_fips_code': 5},
#   {'state_id': 4,
#    'state_name': 'American Samoa',
#    'state_abbr': 'AS',
#    'region_code': 99,
#    'state_fips_code': 60},
#   {'state_id': 5,
#    'state_name': 'Arizona',
#    'state_abbr': 'AZ',
#    'region_code': 4,
#    'state_fips_code': 4},
#   {'state_id': 6,
#    'state_name': 'California',
#    'state_abbr': 'CA',
#    'region_code': 4,
#    'state_fips_code': 6},
#   {'state_id': 7,
#    'state_name': 'Colorado',
#    'state_abbr': 'CO',
#    'region_code': 4,
#    'state_fips_code': 8},
#   {'state_id': 8,
#    'state_name': 'Connecticut',
#    'state_abbr': 'CT',
#    'region_code': 1,
#    'state_fips_code': 9},
#   {'state_id': 9,
#    'state_name': 'Canal Zone',
#    'state_abbr': 'CZ',
#    'region_code': 99,
#    'state_fips_code': None},
#   {'state_id': 10,
#    'state_name': 'District of Columbia',
#    'state_abbr': 'DC',
#    'region_code': 3,
#    'state_fips_code': 11},
#   {'state_id': 11,
#    'state_name': 'Delaware',
#    'state_abbr': 'DE',
#    'region_code': 3,
#    'state_fips_code': 10},
#   {'state_id': 12,
#    'state_name': 'Florida',
#    'state_abbr': 'FL',
#    'region_code': 3,
#    'state_fips_code': 12},
#   {'state_id': 13,
#    'state_name': 'Georgia',
#    'state_abbr': 'GA',
#    'region_code': 3,
#    'state_fips_code': 13},
#   {'state_id': 14,
#    'state_name': 'Guam',
#    'state_abbr': 'GM',
#    'region_code': 0,
#    'state_fips_code': 66},
#   {'state_id': 15,
#    'state_name': 'Hawaii',
#    'state_abbr': 'HI',
#    'region_code': 4,
#    'state_fips_code': 15},
#   {'state_id': 16,
#    'state_name': 'Iowa',
#    'state_abbr': 'IA',
#    'region_code': 2,
#    'state_fips_code': 19},
#   {'state_id': 17,
#    'state_name': 'Idaho',
#    'state_abbr': 'ID',
#    'region_code': 4,
#    'state_fips_code': 16},
#   {'state_id': 18,
#    'state_name': 'Illinois',
#    'state_abbr': 'IL',
#    'region_code': 2,
#    'state_fips_code': 17},
#   {'state_id': 19,
#    'state_name': 'Indiana',
#    'state_abbr': 'IN',
#    'region_code': 2,
#    'state_fips_code': 18},
#   {'state_id': 20,
#    'state_name': 'Kansas',
#    'state_abbr': 'KS',
#    'region_code': 2,
#    'state_fips_code': 20}],
#  'pagination': {'count': 58, 'page': 0, 'pages': 3, 'per_page': 20}}

# %%
# Agencies catalogue data
agencies = f"{FBIurl}api/agencies/list"
agenciesUrl = f"{agencies}?api_key={datagov_key}"
# Retrieve data and convert to json
agenciesCatalogue = requests.get(agenciesUrl).json()
# Out:
# [{'ori': 'AK0010100',
#   'agency_name': 'Anchorage Police Department',
#   'agency_type_name': 'Municipality',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'ANCHORAGE',
#   'nibrs': False,
#   'latitude': 61.17425,
#   'longitude': -149.284329,
#   'nibrs_start_date': None},
#  {'ori': 'AK0010200',
#   'agency_name': 'Fairbanks Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FAIRBANKS NORTH STAR',
#   'nibrs': False,
#   'latitude': 64.83945,
#   'longitude': -147.71942,
#   'nibrs_start_date': None},
#  {'ori': 'AK0010300',
#   'agency_name': 'Juneau Police Department',
#   'agency_type_name': 'City and Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'JUNEAU',
#   'nibrs': False,
#   'latitude': 58.356556,
#   'longitude': -134.50731,
#   'nibrs_start_date': None},
#  {'ori': 'AK0010400',
#   'agency_name': 'Ketchikan Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'KETCHIKAN GATEWAY',
#   'nibrs': False,
#   'latitude': 55.449938,
#   'longitude': -131.106685,
#   'nibrs_start_date': None},
#  {'ori': 'AK0010500',
#   'agency_name': 'Kodiak Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'KODIAK ISLAND',
#   'nibrs': False,
#   'latitude': 57.8049,
#   'longitude': -152.37332,
#   'nibrs_start_date': None},
#  {'ori': 'AK0010600',
#   'agency_name': 'Nome Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'NOME',
#   'nibrs': False,
#   'latitude': 64.783686,
#   'longitude': -164.188912,
#   'nibrs_start_date': None},
#  {'ori': 'AK0010700',
#   'agency_name': 'Petersburg Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'PETERSBURG',
#   'nibrs': False,
#   'latitude': 55.415683,
#   'longitude': -132.875734,
#   'nibrs_start_date': None},
#  {'ori': 'AK0010800',
#   'agency_name': 'Seward Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'KENAI PENINSULA',
#   'nibrs': False,
#   'latitude': 60.366668,
#   'longitude': -152.322283,
#   'nibrs_start_date': None},
#  {'ori': 'AK0010900',
#   'agency_name': 'Sitka Police Department',
#   'agency_type_name': 'City and Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'SITKA',
#   'nibrs': False,
#   'latitude': 57.052124,
#   'longitude': -135.33418,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011000',
#   'agency_name': 'Skagway Police Department',
#   'agency_type_name': 'Municipality',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'SKAGWAY',
#   'nibrs': False,
#   'latitude': 59.575097,
#   'longitude': -135.335418,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011100',
#   'agency_name': 'Wrangell Police Department',
#   'agency_type_name': 'City and Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'WRANGELL',
#   'nibrs': False,
#   'latitude': 56.279121,
#   'longitude': -132.040325,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011200',
#   'agency_name': 'Valdez Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'VALDEZ-CORDOVA',
#   'nibrs': False,
#   'latitude': 61.34984,
#   'longitude': -145.023141,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011300',
#   'agency_name': 'Bethel Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'BETHEL',
#   'nibrs': False,
#   'latitude': 60.928916,
#   'longitude': -160.15335,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011400',
#   'agency_name': 'Cordova Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'VALDEZ-CORDOVA',
#   'nibrs': False,
#   'latitude': 61.34984,
#   'longitude': -145.023141,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011600',
#   'agency_name': 'Kotzebue Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'NORTHWEST ARCTIC',
#   'nibrs': False,
#   'latitude': 67.005066,
#   'longitude': -160.021086,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011700',
#   'agency_name': 'Palmer Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'MATANUSKA-SUSITNA',
#   'nibrs': False,
#   'latitude': 61.602676,
#   'longitude': -149.11183,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011800',
#   'agency_name': 'North Slope Borough Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'NORTH SLOPE',
#   'nibrs': False,
#   'latitude': 69.449343,
#   'longitude': -153.47283,
#   'nibrs_start_date': None},
#  {'ori': 'AK0011900',
#   'agency_name': 'Seldovia Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'KENAI PENINSULA',
#   'nibrs': False,
#   'latitude': 60.366668,
#   'longitude': -152.322283,
#   'nibrs_start_date': None},
#  {'ori': 'AK0012000',
#   'agency_name': 'Soldotna Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'KENAI PENINSULA',
#   'nibrs': False,
#   'latitude': 60.481678,
#   'longitude': -151.07265,
#   'nibrs_start_date': None},
#  {'ori': 'AK0012100',
#   'agency_name': 'Haines Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'HAINES',
#   'nibrs': False,
#   'latitude': 59.098771,
#   'longitude': -135.576936,
#   'nibrs_start_date': None},
#  {'ori': 'AK0012200',
#   'agency_name': 'Homer Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'KENAI PENINSULA',
#   'nibrs': False,
#   'latitude': 59.64873,
#   'longitude': -151.52992,
#   'nibrs_start_date': None},
#  {'ori': 'AK0012300',
#   'agency_name': 'Kenai Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'KENAI PENINSULA',
#   'nibrs': False,
#   'latitude': 60.559402,
#   'longitude': -151.2507,
#   'nibrs_start_date': None},
#  {'ori': 'AK0012500',
#   'agency_name': 'Metlakatla Tribal Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'N/A',
#   'nibrs': False,
#   'latitude': 55.415683,
#   'longitude': -132.875734,
#   'nibrs_start_date': None},
#  {'ori': 'AK0012600',
#   'agency_name': 'Fairbanks International Airport',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'N/A',
#   'nibrs': False,
#   'latitude': 64.81904,
#   'longitude': -147.86464,
#   'nibrs_start_date': None},
#  {'ori': 'AK0012700',
#   'agency_name': 'Anchorage International Airport',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'N/A',
#   'nibrs': False,
#   'latitude': 61.17425,
#   'longitude': -149.284329,
#   'nibrs_start_date': None},
#  {'ori': 'AK0012800',
#   'agency_name': 'Whittier Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'VALDEZ-CORDOVA',
#   'nibrs': False,
#   'latitude': 61.34984,
#   'longitude': -145.023141,
#   'nibrs_start_date': None},
#  {'ori': 'AK0013000',
#   'agency_name': 'Dillingham Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'DILLINGHAM',
#   'nibrs': False,
#   'latitude': 59.824816,
#   'longitude': -158.602233,
#   'nibrs_start_date': None},
#  {'ori': 'AK0013100',
#   'agency_name': 'Hoonah Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'HOONAH-ANGOON',
#   'nibrs': False,
#   'latitude': 58.076434,
#   'longitude': -135.1851,
#   'nibrs_start_date': None},
#  {'ori': 'AK0013200',
#   'agency_name': 'North Pole Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FAIRBANKS NORTH STAR',
#   'nibrs': False,
#   'latitude': 64.75503,
#   'longitude': -147.35081,
#   'nibrs_start_date': None},
#  {'ori': 'AK0013300',
#   'agency_name': 'Unalaska Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'ALEUTIANS WEST',
#   'nibrs': False,
#   'latitude': 51.959447,
#   'longitude': 178.338813,
#   'nibrs_start_date': None},
#  {'ori': 'AK0013500',
#   'agency_name': 'Klawock Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'PRINCE OF WALES-HYDER',
#   'nibrs': False,
#   'latitude': 55.415683,
#   'longitude': -132.875734,
#   'nibrs_start_date': None},
#  {'ori': 'AK0014200',
#   'agency_name': 'University of Alaska: Fairbanks',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'N/A',
#   'nibrs': False,
#   'latitude': 64.691501,
#   'longitude': -146.601909,
#   'nibrs_start_date': None},
#  {'ori': 'AK0014300',
#   'agency_name': 'University of Alaska: Anchorage',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'N/A',
#   'nibrs': False,
#   'latitude': 61.189857,
#   'longitude': -149.81879,
#   'nibrs_start_date': None},
#  {'ori': 'AK0014500',
#   'agency_name': 'Craig Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'PRINCE OF WALES-HYDER',
#   'nibrs': False,
#   'latitude': 55.415683,
#   'longitude': -132.875734,
#   'nibrs_start_date': None},
#  {'ori': 'AK0014600',
#   'agency_name': 'Bristol Bay Borough Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'BRISTOL BAY',
#   'nibrs': False,
#   'latitude': 58.732389,
#   'longitude': -156.986661,
#   'nibrs_start_date': None},
#  {'ori': 'AK0015000',
#   'agency_name': 'St. Paul Police Department',
#   'agency_type_name': 'Census Area',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'ALEUTIANS WEST',
#   'nibrs': False,
#   'latitude': 51.959447,
#   'longitude': 178.338813,
#   'nibrs_start_date': None},
#  {'ori': 'AK0015200',
#   'agency_name': 'Sand Point Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'ALEUTIANS EAST',
#   'nibrs': False,
#   'latitude': 55.245044,
#   'longitude': -161.997477,
#   'nibrs_start_date': None},
#  {'ori': 'AK0015600',
#   'agency_name': 'Wasilla Police Department',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'MATANUSKA-SUSITNA',
#   'nibrs': False,
#   'latitude': 62.182174,
#   'longitude': -149.407974,
#   'nibrs_start_date': None},
#  {'ori': 'AKAST0100',
#   'agency_name': 'State Troopers',
#   'agency_type_name': 'Borough',
#   'state_name': 'Alaska',
#   'state_abbr': 'AK',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'N/A',
#   'nibrs': False,
#   'latitude': 62.182174,
#   'longitude': -149.407974,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010000',
#   'agency_name': "Jefferson County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010100',
#   'agency_name': 'Bessemer Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.396152,
#   'longitude': -86.95345,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010200',
#   'agency_name': 'Birmingham Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SHELBY; JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010300',
#   'agency_name': 'Mountain Brook Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.50124,
#   'longitude': -86.75607,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010400',
#   'agency_name': 'Fairfield Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010500',
#   'agency_name': 'Gardendale Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010600',
#   'agency_name': 'Leeds Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SHELBY; ST CLAIR; JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010700',
#   'agency_name': 'Midfield Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010800',
#   'agency_name': 'Tarrant Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.585728,
#   'longitude': -86.775024,
#   'nibrs_start_date': None},
#  {'ori': 'AL0010900',
#   'agency_name': 'Vestavia Hills Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SHELBY; JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0011000',
#   'agency_name': 'Homewood Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.479603,
#   'longitude': -86.791016,
#   'nibrs_start_date': None},
#  {'ori': 'AL0011100',
#   'agency_name': 'Fultondale Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0011200',
#   'agency_name': 'Hoover Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'SHELBY; JEFFERSON',
#   'nibrs': True,
#   'latitude': 33.38795,
#   'longitude': -86.80636,
#   'nibrs_start_date': '01/01/2006'},
#  {'ori': 'AL0011300',
#   'agency_name': 'Irondale Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.538326,
#   'longitude': -86.70705,
#   'nibrs_start_date': None},
#  {'ori': 'AL0011400',
#   'agency_name': 'Pleasant Grove Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.49046,
#   'longitude': -86.9703,
#   'nibrs_start_date': None},
#  {'ori': 'AL0011800',
#   'agency_name': 'Brighton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.42912,
#   'longitude': -86.94988,
#   'nibrs_start_date': None},
#  {'ori': 'AL0011900',
#   'agency_name': 'Hueytown Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012000',
#   'agency_name': 'Lipscomb Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012100',
#   'agency_name': 'Trussville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ST CLAIR; JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012200',
#   'agency_name': 'Adamsville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012300',
#   'agency_name': 'Warrior Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012400',
#   'agency_name': 'University of Alabama: Birmingham',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.49646,
#   'longitude': -86.80456,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012500',
#   'agency_name': 'Trafford Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012600',
#   'agency_name': 'Morris Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012700',
#   'agency_name': 'Brookside Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0012900',
#   'agency_name': 'Kimberly Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0013200',
#   'agency_name': 'Tannehill Ironworks Historic State Park',
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0013400',
#   'agency_name': 'Jefferson State Community College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.64871,
#   'longitude': -86.7103,
#   'nibrs_start_date': None},
#  {'ori': 'AL0013500',
#   'agency_name': 'Norfolk Southern Railway',
#   'agency_type_name': 'Other',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.545006,
#   'longitude': -86.70188,
#   'nibrs_start_date': None},
#  {'ori': 'AL0014000',
#   'agency_name': 'Lawson State Community College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.553444,
#   'longitude': -86.896536,
#   'nibrs_start_date': None},
#  {'ori': 'AL0014100',
#   'agency_name': 'Samford University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.464043,
#   'longitude': -86.78812,
#   'nibrs_start_date': None},
#  {'ori': 'AL0014500',
#   'agency_name': 'Trussville Fire Department Fire and Explosion Investigation Unit',
#   'agency_type_name': 'Other',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'JEFFERSON',
#   'nibrs': False,
#   'latitude': 33.6301,
#   'longitude': -86.59608,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020000',
#   'agency_name': "Mobile County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.684572,
#   'longitude': -88.196568,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020100',
#   'agency_name': 'Mobile Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.673004,
#   'longitude': -88.09793,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020200',
#   'agency_name': 'Prichard Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.730814,
#   'longitude': -88.0808,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020300',
#   'agency_name': 'Chickasaw Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.684572,
#   'longitude': -88.196568,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020400',
#   'agency_name': 'Citronelle Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 31.089754,
#   'longitude': -88.22756,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020500',
#   'agency_name': 'Saraland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.80567,
#   'longitude': -88.071266,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020600',
#   'agency_name': 'Bayou La Batre Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.684572,
#   'longitude': -88.196568,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020700',
#   'agency_name': 'Satsuma Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.684572,
#   'longitude': -88.196568,
#   'nibrs_start_date': None},
#  {'ori': 'AL0020800',
#   'agency_name': 'Mount Vernon Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.684572,
#   'longitude': -88.196568,
#   'nibrs_start_date': None},
#  {'ori': 'AL0021200',
#   'agency_name': 'Creola Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.684572,
#   'longitude': -88.196568,
#   'nibrs_start_date': None},
#  {'ori': 'AL0021300',
#   'agency_name': 'Mobile Regional Airport',
#   'agency_type_name': 'Other',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.684572,
#   'longitude': -88.196568,
#   'nibrs_start_date': None},
#  {'ori': 'AL0021400',
#   'agency_name': 'University of South Alabama',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.69486,
#   'longitude': -88.17397,
#   'nibrs_start_date': None},
#  {'ori': 'AL0021500',
#   'agency_name': 'Dauphin Island Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.684572,
#   'longitude': -88.196568,
#   'nibrs_start_date': None},
#  {'ori': 'AL0021700',
#   'agency_name': 'Bishop State Community College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MOBILE',
#   'nibrs': False,
#   'latitude': 30.69399,
#   'longitude': -88.056145,
#   'nibrs_start_date': None},
#  {'ori': 'AL0030000',
#   'agency_name': "Montgomery County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONTGOMERY',
#   'nibrs': False,
#   'latitude': 32.20365,
#   'longitude': -86.203831,
#   'nibrs_start_date': None},
#  {'ori': 'AL0030100',
#   'agency_name': 'Montgomery Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONTGOMERY',
#   'nibrs': False,
#   'latitude': 32.20365,
#   'longitude': -86.203831,
#   'nibrs_start_date': None},
#  {'ori': 'AL0030500',
#   'agency_name': 'Alabama Department of Mental Health',
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONTGOMERY',
#   'nibrs': False,
#   'latitude': 32.20365,
#   'longitude': -86.203831,
#   'nibrs_start_date': None},
#  {'ori': 'AL0030600',
#   'agency_name': 'Alabama State University',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONTGOMERY',
#   'nibrs': False,
#   'latitude': 32.20365,
#   'longitude': -86.203831,
#   'nibrs_start_date': None},
#  {'ori': 'AL0030700',
#   'agency_name': 'Auburn University: Montgomery',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONTGOMERY',
#   'nibrs': False,
#   'latitude': 32.20365,
#   'longitude': -86.203831,
#   'nibrs_start_date': None},
#  {'ori': 'AL0030800',
#   'agency_name': 'Alabama Public Service Commission Enforcement Division',
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONTGOMERY',
#   'nibrs': False,
#   'latitude': 32.20365,
#   'longitude': -86.203831,
#   'nibrs_start_date': None},
#  {'ori': 'AL0031400',
#   'agency_name': 'State Fire Marshal',
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONTGOMERY',
#   'nibrs': False,
#   'latitude': 32.20365,
#   'longitude': -86.203831,
#   'nibrs_start_date': None},
#  {'ori': 'AL0033200',
#   'agency_name': 'Department of Corrections Investigations and Intelligence Division',
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'MONTGOMERY',
#   'nibrs': False,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': None},
#  {'ori': 'AL0040000',
#   'agency_name': "Autauga County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'AUTAUGA',
#   'nibrs': False,
#   'latitude': 32.4632,
#   'longitude': -86.47712,
#   'nibrs_start_date': None},
#  {'ori': 'AL0040100',
#   'agency_name': 'Prattville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'ELMORE; AUTAUGA',
#   'nibrs': False,
#   'latitude': 32.459705,
#   'longitude': -86.47263,
#   'nibrs_start_date': None},
#  {'ori': 'AL0040200',
#   'agency_name': 'Autaugaville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'AUTAUGA',
#   'nibrs': False,
#   'latitude': 32.536382,
#   'longitude': -86.64449,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050000',
#   'agency_name': "Baldwin County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.884958,
#   'longitude': -87.775055,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050100',
#   'agency_name': 'Bay Minette Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050200',
#   'agency_name': 'Fairhope Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050300',
#   'agency_name': 'Foley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050400',
#   'agency_name': 'Gulf Shores Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050500',
#   'agency_name': 'Robertsdale Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050600',
#   'agency_name': 'Loxley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050700',
#   'agency_name': 'Silverhill Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050800',
#   'agency_name': 'Daphne Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.599625,
#   'longitude': -87.898056,
#   'nibrs_start_date': None},
#  {'ori': 'AL0050900',
#   'agency_name': 'Summerdale Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0051000',
#   'agency_name': 'Elberta Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0051100',
#   'agency_name': 'Faulkner State Community College',
#   'agency_type_name': 'University or College',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0051200',
#   'agency_name': 'Orange Beach Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0051300',
#   'agency_name': 'Spanish Fort Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BALDWIN',
#   'nibrs': False,
#   'latitude': 30.659218,
#   'longitude': -87.746067,
#   'nibrs_start_date': None},
#  {'ori': 'AL0060000',
#   'agency_name': "Barbour County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARBOUR',
#   'nibrs': False,
#   'latitude': 31.886034,
#   'longitude': -85.4849,
#   'nibrs_start_date': None},
#  {'ori': 'AL0060100',
#   'agency_name': 'Eufaula Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARBOUR',
#   'nibrs': False,
#   'latitude': 31.870253,
#   'longitude': -85.405104,
#   'nibrs_start_date': None},
#  {'ori': 'AL0060200',
#   'agency_name': 'Clayton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARBOUR',
#   'nibrs': False,
#   'latitude': 31.870253,
#   'longitude': -85.405104,
#   'nibrs_start_date': None},
#  {'ori': 'AL0060300',
#   'agency_name': 'Clio Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARBOUR',
#   'nibrs': False,
#   'latitude': 31.870253,
#   'longitude': -85.405104,
#   'nibrs_start_date': None},
#  {'ori': 'AL0060400',
#   'agency_name': 'Louisville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARBOUR',
#   'nibrs': False,
#   'latitude': 31.870253,
#   'longitude': -85.405104,
#   'nibrs_start_date': None},
#  {'ori': 'AL0060700',
#   'agency_name': 'Baker Hill Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BARBOUR',
#   'nibrs': False,
#   'latitude': 31.870253,
#   'longitude': -85.405104,
#   'nibrs_start_date': None},
#  {'ori': 'AL0070000',
#   'agency_name': "Bibb County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BIBB',
#   'nibrs': False,
#   'latitude': 32.939995,
#   'longitude': -87.11683,
#   'nibrs_start_date': None},
#  {'ori': 'AL0070100',
#   'agency_name': 'Centreville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BIBB',
#   'nibrs': False,
#   'latitude': 33.015893,
#   'longitude': -87.127148,
#   'nibrs_start_date': None},
#  {'ori': 'AL0070200',
#   'agency_name': 'Brent Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BIBB',
#   'nibrs': False,
#   'latitude': 33.015893,
#   'longitude': -87.127148,
#   'nibrs_start_date': None},
#  {'ori': 'AL0070300',
#   'agency_name': 'West Blocton Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BIBB',
#   'nibrs': False,
#   'latitude': 33.015893,
#   'longitude': -87.127148,
#   'nibrs_start_date': None},
#  {'ori': 'AL0070400',
#   'agency_name': 'Woodstock Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'TUSCALOOSA; BIBB',
#   'nibrs': False,
#   'latitude': 33.015893,
#   'longitude': -87.127148,
#   'nibrs_start_date': None},
#  {'ori': 'AL0080000',
#   'agency_name': "Blount County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLOUNT',
#   'nibrs': False,
#   'latitude': 33.929085,
#   'longitude': -86.4896,
#   'nibrs_start_date': None},
#  {'ori': 'AL0080100',
#   'agency_name': 'Oneonta Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLOUNT',
#   'nibrs': False,
#   'latitude': 33.943935,
#   'longitude': -86.47508,
#   'nibrs_start_date': None},
#  {'ori': 'AL0080200',
#   'agency_name': 'Blountsville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLOUNT',
#   'nibrs': False,
#   'latitude': 33.977448,
#   'longitude': -86.567246,
#   'nibrs_start_date': None},
#  {'ori': 'AL0080300',
#   'agency_name': 'Cleveland Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLOUNT',
#   'nibrs': False,
#   'latitude': 33.977448,
#   'longitude': -86.567246,
#   'nibrs_start_date': None},
#  {'ori': 'AL0080400',
#   'agency_name': 'Snead Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLOUNT',
#   'nibrs': False,
#   'latitude': 33.977448,
#   'longitude': -86.567246,
#   'nibrs_start_date': None},
#  {'ori': 'AL0080500',
#   'agency_name': 'Highland Lake Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
#   'region_desc': 'Region III',
#   'county_name': 'BLOUNT',
#   'nibrs': False,
#   'latitude': 33.885117,
#   'longitude': -86.41327,
#   'nibrs_start_date': None},
#  {'ori': 'AL0090000',
#   'agency_name': "Bullock County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'Alabama',
#   'state_abbr': 'AL',
#   'division_name': 'East South Central',
#   'region_name': 'South',
# ...
#   'longitude': -121.951543,
#   'nibrs_start_date': None},
#  {'ori': 'CA0070900',
#   'agency_name': 'Pleasant Hill Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 37.96205,
#   'longitude': -122.070656,
#   'nibrs_start_date': None},
#  {'ori': 'CA0071000',
#   'agency_name': 'Richmond Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 37.919479,
#   'longitude': -121.951543,
#   'nibrs_start_date': None},
#  {'ori': 'CA0071100',
#   'agency_name': 'San Pablo Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 37.919479,
#   'longitude': -121.951543,
#   'nibrs_start_date': None},
#  {'ori': 'CA0071200',
#   'agency_name': 'Walnut Creek Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 37.919479,
#   'longitude': -121.951543,
#   'nibrs_start_date': None},
#  {'ori': 'CA0071300',
#   'agency_name': 'Kensington Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 37.919479,
#   'longitude': -121.951543,
#   'nibrs_start_date': None},
#  {'ori': 'CA0071400',
#   'agency_name': 'Martinez Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 38.01375,
#   'longitude': -122.13533,
#   'nibrs_start_date': None},
#  {'ori': 'CA0071500',
#   'agency_name': 'Lafayette Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 38.01906,
#   'longitude': -122.13399,
#   'nibrs_start_date': None},
#  {'ori': 'CA0071600',
#   'agency_name': 'Moraga Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 37.919479,
#   'longitude': -121.951543,
#   'nibrs_start_date': None},
#  {'ori': 'CA0071800',
#   'agency_name': 'San Francisco Bay Area Rapid Transit: Contra Costa County',
#   'agency_type_name': 'Other',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 37.919479,
#   'longitude': -121.951543,
#   'nibrs_start_date': None},
#  {'ori': 'CA0072100',
#   'agency_name': 'Contra Costa Community College',
#   'agency_type_name': 'University or College',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 38.01951,
#   'longitude': -122.13532,
#   'nibrs_start_date': None},
#  {'ori': 'CA007230X',
#   'agency_name': 'Danville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 38.01906,
#   'longitude': -122.13399,
#   'nibrs_start_date': None},
#  {'ori': 'CA007240X',
#   'agency_name': 'San Ramon Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': None},
#  {'ori': 'CA007260X',
#   'agency_name': 'Orinda Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': None},
#  {'ori': 'CA0073300',
#   'agency_name': 'Union Pacific Railroad: Contra Costa County',
#   'agency_type_name': 'Other',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 37.798763,
#   'longitude': -122.24971,
#   'nibrs_start_date': None},
#  {'ori': 'CA007340X',
#   'agency_name': 'Oakley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': None,
#   'longitude': None,
#   'nibrs_start_date': None},
#  {'ori': 'CA0079900',
#   'agency_name': 'Highway Patrol: Contra Costa County',
#   'agency_type_name': 'State Police',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'CONTRA COSTA',
#   'nibrs': False,
#   'latitude': 38.00525,
#   'longitude': -122.07482,
#   'nibrs_start_date': None},
#  {'ori': 'CA0080000',
#   'agency_name': "Del Norte County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'DEL NORTE',
#   'nibrs': False,
#   'latitude': 41.75284,
#   'longitude': -124.20048,
#   'nibrs_start_date': None},
#  {'ori': 'CA0080100',
#   'agency_name': 'Crescent City Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'DEL NORTE',
#   'nibrs': False,
#   'latitude': 41.754265,
#   'longitude': -124.20122,
#   'nibrs_start_date': None},
#  {'ori': 'CA008980X',
#   'agency_name': 'Highway Patrol: Del Norte County',
#   'agency_type_name': 'State Police',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'DEL NORTE',
#   'nibrs': False,
#   'latitude': 41.772213,
#   'longitude': -124.185356,
#   'nibrs_start_date': None},
#  {'ori': 'CA0090000',
#   'agency_name': "El Dorado County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'EL DORADO',
#   'nibrs': False,
#   'latitude': 38.785532,
#   'longitude': -120.534398,
#   'nibrs_start_date': None},
#  {'ori': 'CA0090100',
#   'agency_name': 'Placerville Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'EL DORADO',
#   'nibrs': False,
#   'latitude': 38.73032,
#   'longitude': -120.79018,
#   'nibrs_start_date': None},
#  {'ori': 'CA0090200',
#   'agency_name': 'South Lake Tahoe Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'EL DORADO',
#   'nibrs': False,
#   'latitude': 38.933025,
#   'longitude': -119.97075,
#   'nibrs_start_date': None},
#  {'ori': 'CA009030X',
#   'agency_name': 'Union Pacific Railroad: El Dorado County',
#   'agency_type_name': 'Other',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'EL DORADO',
#   'nibrs': False,
#   'latitude': 37.798763,
#   'longitude': -122.24971,
#   'nibrs_start_date': None},
#  {'ori': 'CA0099900',
#   'agency_name': 'Highway Patrol: El Dorado County',
#   'agency_type_name': 'State Police',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'EL DORADO',
#   'nibrs': False,
#   'latitude': 38.785532,
#   'longitude': -120.534398,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100000',
#   'agency_name': "Fresno County Sheriff's Office",
#   'agency_type_name': 'County',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.761006,
#   'longitude': -119.655019,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100100',
#   'agency_name': 'Clovis Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.82397,
#   'longitude': -119.692795,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100200',
#   'agency_name': 'Coalinga Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.139175,
#   'longitude': -120.362045,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100300',
#   'agency_name': 'Firebaugh Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.761006,
#   'longitude': -119.655019,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100400',
#   'agency_name': 'Fowler Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.630894,
#   'longitude': -119.67752,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100500',
#   'agency_name': 'Fresno Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.761006,
#   'longitude': -119.655019,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100600',
#   'agency_name': 'Huron Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.761006,
#   'longitude': -119.655019,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100700',
#   'agency_name': 'Kerman Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.722088,
#   'longitude': -120.06027,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100800',
#   'agency_name': 'Kingsburg Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.761006,
#   'longitude': -119.655019,
#   'nibrs_start_date': None},
#  {'ori': 'CA0100900',
#   'agency_name': 'Mendota Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.759174,
#   'longitude': -120.373276,
#   'nibrs_start_date': None},
#  {'ori': 'CA0101000',
#   'agency_name': 'Orange Cove Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.761006,
#   'longitude': -119.655019,
#   'nibrs_start_date': None},
#  {'ori': 'CA0101100',
#   'agency_name': 'Parlier Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.761006,
#   'longitude': -119.655019,
#   'nibrs_start_date': None},
#  {'ori': 'CA0101200',
#   'agency_name': 'Reedley Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.598927,
#   'longitude': -119.453575,
#   'nibrs_start_date': None},
#  {'ori': 'CA0101300',
#   'agency_name': 'Sanger Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.70591,
#   'longitude': -119.56111,
#   'nibrs_start_date': None},
#  {'ori': 'CA0101500',
#   'agency_name': 'Selma Police Department',
#   'agency_type_name': 'City',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.567337,
#   'longitude': -119.611984,
#   'nibrs_start_date': None},
#  {'ori': 'CA0101700',
#   'agency_name': 'State Center Community College District',
#   'agency_type_name': 'University or College',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.739437,
#   'longitude': -119.79724,
#   'nibrs_start_date': None},
#  {'ori': 'CA0102400',
#   'agency_name': 'Union Pacific Railroad: Fresno County',
#   'agency_type_name': 'Other',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 37.798763,
#   'longitude': -122.24971,
#   'nibrs_start_date': None},
#  {'ori': 'CA0103000',
#   'agency_name': 'Department of Parks and Recreation: San Joaquin',
#   'agency_type_name': 'Other State Agency',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.761006,
#   'longitude': -119.655019,
#   'nibrs_start_date': None},
#  {'ori': 'CA0109700',
#   'agency_name': 'California State University: Fresno',
#   'agency_type_name': 'University or College',
#   'state_name': 'California',
#   'state_abbr': 'CA',
#   'division_name': 'Pacific',
#   'region_name': 'West',
#   'region_desc': 'Region IV',
#   'county_name': 'FRESNO',
#   'nibrs': False,
#   'latitude': 36.81583,
#   'longitude': -119.748314,
#   'nibrs_start_date': None},
#  ...]

# %%
# National level UCR Estimated Crime data
natCrime = f"{FBIurl}api/estimates/national/1985/2018"
natCrimeUrl = f"{natCrime}?api_key={datagov_key}"
# Retrieve data and convert to json
nationalCrime = requests.get(natCrimeUrl).json()
# Out:
# {'results': [{'state_id': None,
#    'state_abbr': '',
#    'year': 2015,
#    'population': 320896618,
#    'violent_crime': 1199310,
#    'homicide': 15883,
#    'rape_legacy': 91261,
#    'rape_revised': 126134,
#    'robbery': 328109,
#    'aggravated_assault': 764057,
#    'property_crime': 8024115,
#    'burglary': 1587564,
#    'larceny': 5723488,
#    'motor_vehicle_theft': 713063,
#    'arson': 44023},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1985,
#    'population': 237923795,
#    'violent_crime': 1327767,
#    'homicide': 18976,
#    'rape_legacy': 87671,
#    'rape_revised': None,
#    'robbery': 497874,
#    'aggravated_assault': 723246,
#    'property_crime': 11102590,
#    'burglary': 3073348,
#    'larceny': 6926380,
#    'motor_vehicle_theft': 1102862,
#    'arson': 103698},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1997,
#    'population': 267783607,
#    'violent_crime': 1636099,
#    'homicide': 18211,
#    'rape_legacy': 96153,
#    'rape_revised': None,
#    'robbery': 498534,
#    'aggravated_assault': 1023201,
#    'property_crime': 11558975,
#    'burglary': 2461026,
#    'larceny': 7743760,
#    'motor_vehicle_theft': 1354189,
#    'arson': 87332},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1998,
#    'population': 270248003,
#    'violent_crime': 1533887,
#    'homicide': 16974,
#    'rape_legacy': 93144,
#    'rape_revised': None,
#    'robbery': 447186,
#    'aggravated_assault': 976583,
#    'property_crime': 10951827,
#    'burglary': 2332735,
#    'larceny': 7376311,
#    'motor_vehicle_theft': 1242781,
#    'arson': 80427},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1999,
#    'population': 272690813,
#    'violent_crime': 1426044,
#    'homicide': 15522,
#    'rape_legacy': 89411,
#    'rape_revised': None,
#    'robbery': 409371,
#    'aggravated_assault': 911740,
#    'property_crime': 10208334,
#    'burglary': 2100739,
#    'larceny': 6955520,
#    'motor_vehicle_theft': 1152075,
#    'arson': 78498},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2000,
#    'population': 281421906,
#    'violent_crime': 1425486,
#    'homicide': 15586,
#    'rape_legacy': 90178,
#    'rape_revised': None,
#    'robbery': 408016,
#    'aggravated_assault': 911706,
#    'property_crime': 10182584,
#    'burglary': 2050992,
#    'larceny': 6971590,
#    'motor_vehicle_theft': 1160002,
#    'arson': 69466},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2001,
#    'population': 285317559,
#    'violent_crime': 1439480,
#    'homicide': 16037,
#    'rape_legacy': 90863,
#    'rape_revised': None,
#    'robbery': 423557,
#    'aggravated_assault': 909023,
#    'property_crime': 10437189,
#    'burglary': 2116531,
#    'larceny': 7092267,
#    'motor_vehicle_theft': 1228391,
#    'arson': 79040},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2002,
#    'population': 287973924,
#    'violent_crime': 1423677,
#    'homicide': 16229,
#    'rape_legacy': 95235,
#    'rape_revised': None,
#    'robbery': 420806,
#    'aggravated_assault': 891407,
#    'property_crime': 10455277,
#    'burglary': 2151252,
#    'larceny': 7057379,
#    'motor_vehicle_theft': 1246646,
#    'arson': 77148},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2003,
#    'population': 290788976,
#    'violent_crime': 1383676,
#    'homicide': 16528,
#    'rape_legacy': 93883,
#    'rape_revised': None,
#    'robbery': 414235,
#    'aggravated_assault': 859030,
#    'property_crime': 10442862,
#    'burglary': 2154834,
#    'larceny': 7026802,
#    'motor_vehicle_theft': 1261226,
#    'arson': 72809},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2004,
#    'population': 293656842,
#    'violent_crime': 1360088,
#    'homicide': 16148,
#    'rape_legacy': 95089,
#    'rape_revised': None,
#    'robbery': 401470,
#    'aggravated_assault': 847381,
#    'property_crime': 10319386,
#    'burglary': 2144446,
#    'larceny': 6937089,
#    'motor_vehicle_theft': 1237851,
#    'arson': 69302},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2005,
#    'population': 296507061,
#    'violent_crime': 1390745,
#    'homicide': 16740,
#    'rape_legacy': 94347,
#    'rape_revised': None,
#    'robbery': 417438,
#    'aggravated_assault': 862220,
#    'property_crime': 10174754,
#    'burglary': 2155448,
#    'larceny': 6783447,
#    'motor_vehicle_theft': 1235859,
#    'arson': 68510},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2006,
#    'population': 299398484,
#    'violent_crime': 1435123,
#    'homicide': 17309,
#    'rape_legacy': 94472,
#    'rape_revised': None,
#    'robbery': 449246,
#    'aggravated_assault': 874096,
#    'property_crime': 10019601,
#    'burglary': 2194993,
#    'larceny': 6626363,
#    'motor_vehicle_theft': 1198245,
#    'arson': 72969},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2007,
#    'population': 301621157,
#    'violent_crime': 1422970,
#    'homicide': 17128,
#    'rape_legacy': 92160,
#    'rape_revised': None,
#    'robbery': 447324,
#    'aggravated_assault': 866358,
#    'property_crime': 9882212,
#    'burglary': 2190198,
#    'larceny': 6591542,
#    'motor_vehicle_theft': 1100472,
#    'arson': 68091},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2008,
#    'population': 304059724,
#    'violent_crime': 1394461,
#    'homicide': 16465,
#    'rape_legacy': 90750,
#    'rape_revised': None,
#    'robbery': 443563,
#    'aggravated_assault': 843683,
#    'property_crime': 9774152,
#    'burglary': 2228887,
#    'larceny': 6586206,
#    'motor_vehicle_theft': 959059,
#    'arson': 65790},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2009,
#    'population': 307006550,
#    'violent_crime': 1325896,
#    'homicide': 15399,
#    'rape_legacy': 89241,
#    'rape_revised': None,
#    'robbery': 408742,
#    'aggravated_assault': 812514,
#    'property_crime': 9337060,
#    'burglary': 2203313,
#    'larceny': 6338095,
#    'motor_vehicle_theft': 795652,
#    'arson': 59862},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2010,
#    'population': 309330219,
#    'violent_crime': 1251248,
#    'homicide': 14722,
#    'rape_legacy': 85593,
#    'rape_revised': None,
#    'robbery': 369089,
#    'aggravated_assault': 781844,
#    'property_crime': 9112625,
#    'burglary': 2168459,
#    'larceny': 6204601,
#    'motor_vehicle_theft': 739565,
#    'arson': 55987},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2011,
#    'population': 311587816,
#    'violent_crime': 1206031,
#    'homicide': 14661,
#    'rape_legacy': 84175,
#    'rape_revised': None,
#    'robbery': 354772,
#    'aggravated_assault': 752423,
#    'property_crime': 9052743,
#    'burglary': 2185140,
#    'larceny': 6151095,
#    'motor_vehicle_theft': 716508,
#    'arson': 54548},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1986,
#    'population': 240132887,
#    'violent_crime': 1489169,
#    'homicide': 20613,
#    'rape_legacy': 91459,
#    'rape_revised': None,
#    'robbery': 542775,
#    'aggravated_assault': 834322,
#    'property_crime': 11722700,
#    'burglary': 3241410,
#    'larceny': 7257153,
#    'motor_vehicle_theft': 1224137,
#    'arson': 111163},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1987,
#    'population': 242288918,
#    'violent_crime': 1483999,
#    'homicide': 20096,
#    'rape_legacy': 91111,
#    'rape_revised': None,
#    'robbery': 517704,
#    'aggravated_assault': 855088,
#    'property_crime': 12024709,
#    'burglary': 3236184,
#    'larceny': 7499851,
#    'motor_vehicle_theft': 1288674,
#    'arson': 102914},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1988,
#    'population': 244498982,
#    'violent_crime': 1566221,
#    'homicide': 20675,
#    'rape_legacy': 92486,
#    'rape_revised': None,
#    'robbery': 542968,
#    'aggravated_assault': 910092,
#    'property_crime': 12356865,
#    'burglary': 3218077,
#    'larceny': 7705872,
#    'motor_vehicle_theft': 1432916,
#    'arson': 100212},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1989,
#    'population': 246819230,
#    'violent_crime': 1646037,
#    'homicide': 21500,
#    'rape_legacy': 94504,
#    'rape_revised': None,
#    'robbery': 578326,
#    'aggravated_assault': 951707,
#    'property_crime': 12605412,
#    'burglary': 3168170,
#    'larceny': 7872442,
#    'motor_vehicle_theft': 1564800,
#    'arson': 102187},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1990,
#    'population': 249464396,
#    'violent_crime': 1820127,
#    'homicide': 23438,
#    'rape_legacy': 102555,
#    'rape_revised': None,
#    'robbery': 639271,
#    'aggravated_assault': 1054863,
#    'property_crime': 12655486,
#    'burglary': 3073909,
#    'larceny': 7945670,
#    'motor_vehicle_theft': 1635907,
#    'arson': 104088},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1991,
#    'population': 252153092,
#    'violent_crime': 1911767,
#    'homicide': 24703,
#    'rape_legacy': 106593,
#    'rape_revised': None,
#    'robbery': 687732,
#    'aggravated_assault': 1092739,
#    'property_crime': 12961116,
#    'burglary': 3157150,
#    'larceny': 8142228,
#    'motor_vehicle_theft': 1661738,
#    'arson': 103299},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1992,
#    'population': 255029699,
#    'violent_crime': 1932274,
#    'homicide': 23760,
#    'rape_legacy': 109062,
#    'rape_revised': None,
#    'robbery': 672478,
#    'aggravated_assault': 1126974,
#    'property_crime': 12505917,
#    'burglary': 2979884,
#    'larceny': 7915199,
#    'motor_vehicle_theft': 1610834,
#    'arson': 103979},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1993,
#    'population': 257782608,
#    'violent_crime': 1926017,
#    'homicide': 24526,
#    'rape_legacy': 106014,
#    'rape_revised': None,
#    'robbery': 659870,
#    'aggravated_assault': 1135607,
#    'property_crime': 12218777,
#    'burglary': 2834808,
#    'larceny': 7820909,
#    'motor_vehicle_theft': 1563060,
#    'arson': 97138},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1994,
#    'population': 260327021,
#    'violent_crime': 1857670,
#    'homicide': 23326,
#    'rape_legacy': 102216,
#    'rape_revised': None,
#    'robbery': 618949,
#    'aggravated_assault': 1113179,
#    'property_crime': 12131873,
#    'burglary': 2712774,
#    'larceny': 7879812,
#    'motor_vehicle_theft': 1539287,
#    'arson': 103187},
#   {'state_id': None,
#    'state_abbr': None,
#    'year': 2017,
#    'population': 325147121,
#    'violent_crime': 1283875,
#    'homicide': 17294,
#    'rape_legacy': None,
#    'rape_revised': 135666,
#    'robbery': 320596,
#    'aggravated_assault': 810319,
#    'property_crime': 7682988,
#    'burglary': 1397045,
#    'larceny': 5513000,
#    'motor_vehicle_theft': 772943,
#    'arson': 42961},
#   {'state_id': None,
#    'state_abbr': None,
#    'year': 2018,
#    'population': 327167434,
#    'violent_crime': 1245065,
#    'homicide': 16214,
#    'rape_legacy': None,
#    'rape_revised': 139380,
#    'robbery': 282061,
#    'aggravated_assault': 807410,
#    'property_crime': 7196045,
#    'burglary': 1230149,
#    'larceny': 5217055,
#    'motor_vehicle_theft': 748841,
#    'arson': 37835},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2012,
#    'population': 313873685,
#    'violent_crime': 1217057,
#    'homicide': 14856,
#    'rape_legacy': 85141,
#    'rape_revised': None,
#    'robbery': 355051,
#    'aggravated_assault': 762009,
#    'property_crime': 9001992,
#    'burglary': 2109932,
#    'larceny': 6168874,
#    'motor_vehicle_theft': 723186,
#    'arson': 55349},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2013,
#    'population': 316497531,
#    'violent_crime': 1168298,
#    'homicide': 14319,
#    'rape_legacy': 82109,
#    'rape_revised': 113695,
#    'robbery': 345093,
#    'aggravated_assault': 726777,
#    'property_crime': 8651892,
#    'burglary': 1932139,
#    'larceny': 6019465,
#    'motor_vehicle_theft': 700288,
#    'arson': 47219},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2014,
#    'population': 318907401,
#    'violent_crime': 1153022,
#    'homicide': 14164,
#    'rape_legacy': 84864,
#    'rape_revised': 118027,
#    'robbery': 322905,
#    'aggravated_assault': 731089,
#    'property_crime': 8209010,
#    'burglary': 1713153,
#    'larceny': 5809054,
#    'motor_vehicle_theft': 686803,
#    'arson': 46220},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1995,
#    'population': 262803276,
#    'violent_crime': 1798792,
#    'homicide': 21606,
#    'rape_legacy': 97470,
#    'rape_revised': None,
#    'robbery': 580509,
#    'aggravated_assault': 1099207,
#    'property_crime': 12063935,
#    'burglary': 2593784,
#    'larceny': 7997710,
#    'motor_vehicle_theft': 1472441,
#    'arson': 96547},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 2016,
#    'population': 323405935,
#    'violent_crime': 1285606,
#    'homicide': 17413,
#    'rape_legacy': 96970,
#    'rape_revised': 132414,
#    'robbery': 332797,
#    'aggravated_assault': 802982,
#    'property_crime': 7928530,
#    'burglary': 1516405,
#    'larceny': 5644835,
#    'motor_vehicle_theft': 767290,
#    'arson': 45775},
#   {'state_id': None,
#    'state_abbr': '',
#    'year': 1996,
#    'population': 265228572,
#    'violent_crime': 1688540,
#    'homicide': 19645,
#    'rape_legacy': 96252,
#    'rape_revised': None,
#    'robbery': 535594,
#    'aggravated_assault': 1037049,
#    'property_crime': 11805323,
#    'burglary': 2506400,
#    'larceny': 7904685,
#    'motor_vehicle_theft': 1394238,
#    'arson': 91719}],
#  'pagination': {'count': 34, 'page': 0, 'pages': 1, 'per_page': 0}}

# %%
# National level Arrest Demographic data
natArrest = f"{FBIurl}api/arrest/national/offense/all/1985/2018"
natArrestUrl = f"{natArrest}?api_key={datagov_key}"
# Retrieve data and convert to json
nationalArrest = requests.get(natArrestUrl).json()
# Out:
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 264388,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 299203,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 301739,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 311363,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 354344,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 396039,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 373762,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 457470,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 451196,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 457303,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 466482,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 403429,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 411986,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 393001,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 368807,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 365570,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 375391,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 362271,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 346454,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 333778,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 347248,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 340284,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 340507,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 341003,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 341051,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 330032,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 316529,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 315876,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 305712,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 299479,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 304892,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 318788,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 342593,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 324056,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 2171804,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2324490,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2430918,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2243824,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2460115,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2675304,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2529147,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3076845,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2978037,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3113375,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3092722,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2951446,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3085613,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3131106,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3007237,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2963415,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2998653,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2837542,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2853640,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2944498,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3062134,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3100963,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3144611,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3073869,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3087929,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3033667,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2867217,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2820546,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2740785,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2619956,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2647018,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2755770,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 3039334,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 2708654,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 17082, 'data_year': 1985, 'month_num': 0, 'key': 'Arson'},
#   {'value': 15895, 'data_year': 1986, 'month_num': 0, 'key': 'Arson'},
#   {'value': 15169, 'data_year': 1987, 'month_num': 0, 'key': 'Arson'},
#   {'value': 14886, 'data_year': 1988, 'month_num': 0, 'key': 'Arson'},
#   {'value': 14655, 'data_year': 1989, 'month_num': 0, 'key': 'Arson'},
#   {'value': 15700, 'data_year': 1990, 'month_num': 0, 'key': 'Arson'},
#   {'value': 15423, 'data_year': 1991, 'month_num': 0, 'key': 'Arson'},
#   {'value': 17059, 'data_year': 1992, 'month_num': 0, 'key': 'Arson'},
#   {'value': 16590, 'data_year': 1993, 'month_num': 0, 'key': 'Arson'},
#   {'value': 16970, 'data_year': 1994, 'month_num': 0, 'key': 'Arson'},
#   {'value': 16419, 'data_year': 1995, 'month_num': 0, 'key': 'Arson'},
#   {'value': 14578, 'data_year': 1996, 'month_num': 0, 'key': 'Arson'},
#   {'value': 14213, 'data_year': 1997, 'month_num': 0, 'key': 'Arson'},
#   {'value': 12670, 'data_year': 1998, 'month_num': 0, 'key': 'Arson'},
#   {'value': 12264, 'data_year': 1999, 'month_num': 0, 'key': 'Arson'},
#   {'value': 12250, 'data_year': 2000, 'month_num': 0, 'key': 'Arson'},
#   {'value': 13057, 'data_year': 2001, 'month_num': 0, 'key': 'Arson'},
#   {'value': 12731, 'data_year': 2002, 'month_num': 0, 'key': 'Arson'},
#   {'value': 12251, 'data_year': 2003, 'month_num': 0, 'key': 'Arson'},
#   {'value': 11912, 'data_year': 2004, 'month_num': 0, 'key': 'Arson'},
#   {'value': 12955, 'data_year': 2005, 'month_num': 0, 'key': 'Arson'},
#   {'value': 12621, 'data_year': 2006, 'month_num': 0, 'key': 'Arson'},
#   {'value': 11969, 'data_year': 2007, 'month_num': 0, 'key': 'Arson'},
#   {'value': 11583, 'data_year': 2008, 'month_num': 0, 'key': 'Arson'},
#   {'value': 9882, 'data_year': 2009, 'month_num': 0, 'key': 'Arson'},
#   {'value': 9220, 'data_year': 2010, 'month_num': 0, 'key': 'Arson'},
#   {'value': 9320, 'data_year': 2011, 'month_num': 0, 'key': 'Arson'},
#   {'value': 9437, 'data_year': 2012, 'month_num': 0, 'key': 'Arson'},
#   {'value': 8533, 'data_year': 2013, 'month_num': 0, 'key': 'Arson'},
#   {'value': 7612, 'data_year': 2014, 'month_num': 0, 'key': 'Arson'},
#   {'value': 7209, 'data_year': 2015, 'month_num': 0, 'key': 'Arson'},
#   {'value': 8842, 'data_year': 2016, 'month_num': 0, 'key': 'Arson'},
#   {'value': 7745, 'data_year': 2017, 'month_num': 0, 'key': 'Arson'},
#   {'value': 7541, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 389113, 'data_year': 1985, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 386257, 'data_year': 1986, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 374965, 'data_year': 1987, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 338317, 'data_year': 1988, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 355471, 'data_year': 1989, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 360453, 'data_year': 1990, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 334711, 'data_year': 1991, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 376898, 'data_year': 1992, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 348081, 'data_year': 1993, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 326140, 'data_year': 1994, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 312195, 'data_year': 1995, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 279296, 'data_year': 1996, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 266089, 'data_year': 1997, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 249770, 'data_year': 1998, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 218999, 'data_year': 1999, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 211811, 'data_year': 2000, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 218846, 'data_year': 2001, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 220694, 'data_year': 2002, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 223693, 'data_year': 2003, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 224929, 'data_year': 2004, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 232335, 'data_year': 2005, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 232806, 'data_year': 2006, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 239653, 'data_year': 2007, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 246464, 'data_year': 2008, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 243136, 'data_year': 2009, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 234978, 'data_year': 2010, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 237148, 'data_year': 2011, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 232370, 'data_year': 2012, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 206550, 'data_year': 2013, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 192878, 'data_year': 2014, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 177117, 'data_year': 2015, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 174334, 'data_year': 2016, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 180460, 'data_year': 2017, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 148488, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 71820,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 72629,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 77556,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 69040,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 64445,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 71988,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 74726,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 77159,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 84767,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 110669,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 121065,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 147256,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 158107,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 142327,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 122115,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 113076,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 103992,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 106930,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 106209,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 102753,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 109913,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 117506,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 114852,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 107183,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 91066,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 74846,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 61594,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 59367,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 48426,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 42289,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 35944,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 27903,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 24414,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 17605,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 640957,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 622113,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 599627,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 588731,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 645162,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 615446,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 578318,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 692072,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 669115,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 615298,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 660832,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 656769,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 636646,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 561839,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 505691,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 511261,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 521754,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 521154,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 533684,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 511626,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 537444,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 548684,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 566121,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 549253,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 531945,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 499017,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 468783,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 447067,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 393738,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 353314,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 321275,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 314581,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 291377,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 271253,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 1510356,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1468122,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1410399,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1302881,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1327005,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1435962,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1311235,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1359705,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1242026,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1143257,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1077351,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1094694,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1011249,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1012700,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1019510,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 997066,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 985111,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1080636,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1065034,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1065006,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1050376,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1082216,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1106698,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1170893,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1166510,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1119117,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 971392,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1030572,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 1003749,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 893791,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 875625,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 856253,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 835885,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 793552,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 726055,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 730784,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 811080,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 865609,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1072663,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 908189,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 790166,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 989047,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1020270,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1141218,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1264747,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1192800,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1271112,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1288303,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1247639,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1282126,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1281287,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1204567,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1261705,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1326334,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1424151,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1438196,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1446481,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1354421,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1345544,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1311802,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1218450,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1253236,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1291436,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1255221,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1199881,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1311575,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1474525,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 1352038,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 834841, 'data_year': 1985, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 784159, 'data_year': 1986, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 700673, 'data_year': 1987, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 613277, 'data_year': 1988, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 668277, 'data_year': 1989, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 738707, 'data_year': 1990, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 672379, 'data_year': 1991, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 686790, 'data_year': 1992, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 622811, 'data_year': 1993, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 581564, 'data_year': 1994, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 558902, 'data_year': 1995, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 545911, 'data_year': 1996, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 536646, 'data_year': 1997, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 527781, 'data_year': 1998, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 500725, 'data_year': 1999, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 480069, 'data_year': 2000, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 454548, 'data_year': 2001, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 440756, 'data_year': 2002, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 421656, 'data_year': 2003, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 430727, 'data_year': 2004, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 429106, 'data_year': 2005, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 433077, 'data_year': 2006, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 473073, 'data_year': 2007, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 495537, 'data_year': 2008, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 493649, 'data_year': 2009, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 455407, 'data_year': 2010, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 429991, 'data_year': 2011, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 412122, 'data_year': 2012, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 392680, 'data_year': 2013, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 333626, 'data_year': 2014, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 336664, 'data_year': 2015, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 312881, 'data_year': 2016, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 302863, 'data_year': 2017, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 269022, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 9816, 'data_year': 1985, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 10509, 'data_year': 1986, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 10639, 'data_year': 1987, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 11735, 'data_year': 1988, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13002, 'data_year': 1989, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12464, 'data_year': 1990, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 10911, 'data_year': 1991, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12232, 'data_year': 1992, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 11398, 'data_year': 1993, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 11887, 'data_year': 1994, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12196, 'data_year': 1995, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12552, 'data_year': 1996, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13197, 'data_year': 1997, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13186, 'data_year': 1998, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13486, 'data_year': 1999, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 14578, 'data_year': 2000, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 15764, 'data_year': 2001, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 14601, 'data_year': 2002, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13490, 'data_year': 2003, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13694, 'data_year': 2004, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 14791, 'data_year': 2005, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 15500, 'data_year': 2006, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 17636, 'data_year': 2007, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 17304, 'data_year': 2008, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 14634, 'data_year': 2009, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13439, 'data_year': 2010, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12919, 'data_year': 2011, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12935, 'data_year': 2012, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12918, 'data_year': 2013, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13101, 'data_year': 2014, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12980, 'data_year': 2015, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13639, 'data_year': 2016, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 14313, 'data_year': 2017, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12201, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 75740,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 77714,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 78818,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 74716,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 80552,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 77374,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 78968,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 91934,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 91414,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 95525,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 99016,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 94257,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 93802,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 90376,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 84109,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 84570,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 92101,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 90076,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 87472,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 93155,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 93119,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 83519,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 82059,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 73092,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 69788,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 62542,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 56521,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 54847,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 49633,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 45986,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 45264,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 47830,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 48236,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 42208,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 288417, 'data_year': 1985, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 286074, 'data_year': 1986, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 280812, 'data_year': 1987, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 262305, 'data_year': 1988, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 289689, 'data_year': 1989, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 285034, 'data_year': 1990, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 297046, 'data_year': 1991, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 358152, 'data_year': 1992, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 340687, 'data_year': 1993, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 336326, 'data_year': 1994, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 335465, 'data_year': 1995, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 339589, 'data_year': 1996, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 331519, 'data_year': 1997, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 321298, 'data_year': 1998, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 312967, 'data_year': 1999, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 277701, 'data_year': 2000, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 269873, 'data_year': 2001, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 260595, 'data_year': 2002, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 249097, 'data_year': 2003, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 244157, 'data_year': 2004, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 253594, 'data_year': 2005, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 216896, 'data_year': 2006, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 201823, 'data_year': 2007, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 188998, 'data_year': 2008, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 174383, 'data_year': 2009, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 152426, 'data_year': 2010, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 132422, 'data_year': 2011, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 125228, 'data_year': 2012, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 115458, 'data_year': 2013, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 113553, 'data_year': 2014, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 109599, 'data_year': 2015, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 109259, 'data_year': 2016, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 114805, 'data_year': 2017, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 100668, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 31714,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 29338,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 22762,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 18442,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 16399,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 15917,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 13144,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 18050,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 17923,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 16153,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 18704,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 17637,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 19112,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 16041,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 13807,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 13179,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 14151,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 8132,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 8332,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 7879,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 8156,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 9277,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 9461,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 7841,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 8196,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 7664,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 6670,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 6145,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 5105,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 4473,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 3714,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 3026,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 2665,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 2732,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 3,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 367,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 551,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2008,
#    'month_num': 0,
# ...
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 71946,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 71951,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 69604,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 67977,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 70170,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 65373,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 65484,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 62538,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 61680,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 58003,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 55136,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 55506,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 46500,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 44478,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 41691,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 42436,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 42069,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 38204,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 587121,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 639900,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 671943,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 697400,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 769601,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 830410,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 809124,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 987934,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1016269,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1020517,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1099470,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1039801,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1047375,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1025721,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 981871,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 983146,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1011866,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 998130,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 978445,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 996566,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1018073,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1007128,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1038727,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1041659,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1069708,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1043222,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 1001972,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 980138,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 912470,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 887091,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 887937,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 907886,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 957405,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 878930,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Simple Assault'},
#   {'value': 111350,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 116560,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 119048,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 126247,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 141598,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 135874,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 132482,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 143055,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 138279,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 137952,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 135860,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 120051,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 116284,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 105982,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 89851,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 94118,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 97130,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 98672,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 99192,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 99427,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 103811,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 94460,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 95512,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 88782,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 85212,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 76711,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 75032,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 80162,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 75844,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 72306,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 72841,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 79460,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 82932,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 78788,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 11230, 'data_year': 1985, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 12181, 'data_year': 1986, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 11670, 'data_year': 1987, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 11066, 'data_year': 1988, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 13868, 'data_year': 1989, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 17875, 'data_year': 1990, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 14781, 'data_year': 1991, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 15482, 'data_year': 1992, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 10737, 'data_year': 1993, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 11599, 'data_year': 1994, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 9154, 'data_year': 1995, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 4903, 'data_year': 1996, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 4482, 'data_year': 1997, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 3830, 'data_year': 1998, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 5110, 'data_year': 1999, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 3850, 'data_year': 2000, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 2897, 'data_year': 2001, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 8091, 'data_year': 2002, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 2008, 'data_year': 2003, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 4804, 'data_year': 2004, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 2966, 'data_year': 2005, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1930, 'data_year': 2006, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1610, 'data_year': 2007, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1263, 'data_year': 2008, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1599, 'data_year': 2009, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 913, 'data_year': 2010, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1154, 'data_year': 2011, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1287, 'data_year': 2012, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 857, 'data_year': 2013, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1079, 'data_year': 2014, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1411, 'data_year': 2015, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1052, 'data_year': 2016, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 734, 'data_year': 2017, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 447, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 29842, 'data_year': 1985, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 32994, 'data_year': 1986, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 32518, 'data_year': 1987, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 29348, 'data_year': 1988, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 29585, 'data_year': 1989, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 31584, 'data_year': 1990, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 31690, 'data_year': 1991, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 30991, 'data_year': 1992, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 24834, 'data_year': 1993, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 21925, 'data_year': 1994, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 21094, 'data_year': 1995, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 22801, 'data_year': 1996, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 23954, 'data_year': 1997, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 26870, 'data_year': 1998, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 27006, 'data_year': 1999, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 28483, 'data_year': 2000, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 27330, 'data_year': 2001, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 21505, 'data_year': 2002, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 22725, 'data_year': 2003, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 28011, 'data_year': 2004, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 30751, 'data_year': 2005, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 29211, 'data_year': 2006, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 26878, 'data_year': 2007, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 26968, 'data_year': 2008, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 27057, 'data_year': 2009, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 25586, 'data_year': 2010, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 23129, 'data_year': 2011, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 22170, 'data_year': 2012, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 21657, 'data_year': 2013, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 22005, 'data_year': 2014, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 20197, 'data_year': 2015, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 20174, 'data_year': 2016, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 18896, 'data_year': 2017, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 18581, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 233444, 'data_year': 1985, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 233068, 'data_year': 1986, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 230090, 'data_year': 1987, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 228769, 'data_year': 1988, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 246805, 'data_year': 1989, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 266743, 'data_year': 1990, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 258312, 'data_year': 1991, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 282738, 'data_year': 1992, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 273957, 'data_year': 1993, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 267821, 'data_year': 1994, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 263230, 'data_year': 1995, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 252374, 'data_year': 1996, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 241495, 'data_year': 1997, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 230187, 'data_year': 1998, 'month_num': 0, 'key': 'Vandalism'},
#   ...],
#  'precise_data': []}

# %%
# National level UCR Police Employment data
natPolEmployment = f"{FBIurl}api/police-employment/national//1985/2018"
natPolEmploymentUrl = f"{natPolEmployment}?api_key={datagov_key}"
# Retrieve data and convert to json
nationalPolEmployment = requests.get(natPolEmploymentUrl).json()
# Out:
# {'results': [{'data_year': 1985,
#    'civilian_ct': 153996,
#    'female_civilian_ct': 98509,
#    'female_officer_ct': 33048,
#    'female_total_ct': 131557,
#    'male_civilian_ct': 55487,
#    'male_officer_ct': 460259,
#    'male_total_ct': 515746,
#    'population': 242487508,
#    'total_pe_ct': 647303,
#    'agency_count_pe_submitting': 14081,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.67},
#   {'data_year': 1986,
#    'civilian_ct': 160071,
#    'female_civilian_ct': 102160,
#    'female_officer_ct': 36028,
#    'female_total_ct': 138188,
#    'male_civilian_ct': 57911,
#    'male_officer_ct': 468139,
#    'male_total_ct': 526050,
#    'population': 244909160,
#    'total_pe_ct': 664238,
#    'agency_count_pe_submitting': 14140,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.71},
#   {'data_year': 1987,
#    'civilian_ct': 167909,
#    'female_civilian_ct': 107230,
#    'female_officer_ct': 38009,
#    'female_total_ct': 145239,
#    'male_civilian_ct': 60679,
#    'male_officer_ct': 472712,
#    'male_total_ct': 533391,
#    'population': 247674898,
#    'total_pe_ct': 678630,
#    'agency_count_pe_submitting': 14063,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.74},
#   {'data_year': 1988,
#    'civilian_ct': 174263,
#    'female_civilian_ct': 112393,
#    'female_officer_ct': 39988,
#    'female_total_ct': 152381,
#    'male_civilian_ct': 61870,
#    'male_officer_ct': 475168,
#    'male_total_ct': 537038,
#    'population': 250263626,
#    'total_pe_ct': 689419,
#    'agency_count_pe_submitting': 12904,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.75},
#   {'data_year': 1989,
#    'civilian_ct': 188696,
#    'female_civilian_ct': 120754,
#    'female_officer_ct': 43158,
#    'female_total_ct': 163912,
#    'male_civilian_ct': 67942,
#    'male_officer_ct': 488880,
#    'male_total_ct': 556822,
#    'population': 252766828,
#    'total_pe_ct': 720734,
#    'agency_count_pe_submitting': 14116,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.85},
#   {'data_year': 1990,
#    'civilian_ct': 197420,
#    'female_civilian_ct': 126968,
#    'female_officer_ct': 46741,
#    'female_total_ct': 173709,
#    'male_civilian_ct': 70452,
#    'male_officer_ct': 501792,
#    'male_total_ct': 572244,
#    'population': 253286315,
#    'total_pe_ct': 745953,
#    'agency_count_pe_submitting': 13920,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.95},
#   {'data_year': 1991,
#    'civilian_ct': 207621,
#    'female_civilian_ct': 133382,
#    'female_officer_ct': 50235,
#    'female_total_ct': 183617,
#    'male_civilian_ct': 74239,
#    'male_officer_ct': 517275,
#    'male_total_ct': 591514,
#    'population': 260760111,
#    'total_pe_ct': 775131,
#    'agency_count_pe_submitting': 13928,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.97},
#   {'data_year': 1992,
#    'civilian_ct': 212221,
#    'female_civilian_ct': 135130,
#    'female_officer_ct': 52146,
#    'female_total_ct': 187276,
#    'male_civilian_ct': 77091,
#    'male_officer_ct': 524692,
#    'male_total_ct': 601783,
#    'population': 263995383,
#    'total_pe_ct': 789059,
#    'agency_count_pe_submitting': 14154,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.99},
#   {'data_year': 1993,
#    'civilian_ct': 224433,
#    'female_civilian_ct': 141559,
#    'female_officer_ct': 54279,
#    'female_total_ct': 195838,
#    'male_civilian_ct': 82874,
#    'male_officer_ct': 537488,
#    'male_total_ct': 620362,
#    'population': 268848321,
#    'total_pe_ct': 816200,
#    'agency_count_pe_submitting': 13362,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.04},
#   {'data_year': 1994,
#    'civilian_ct': 239890,
#    'female_civilian_ct': 149360,
#    'female_officer_ct': 58634,
#    'female_total_ct': 207994,
#    'male_civilian_ct': 90530,
#    'male_officer_ct': 559464,
#    'male_total_ct': 649994,
#    'population': 273258089,
#    'total_pe_ct': 857988,
#    'agency_count_pe_submitting': 13380,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.14},
#   {'data_year': 1995,
#    'civilian_ct': 248450,
#    'female_civilian_ct': 154000,
#    'female_officer_ct': 63329,
#    'female_total_ct': 217329,
#    'male_civilian_ct': 94450,
#    'male_officer_ct': 580221,
#    'male_total_ct': 674671,
#    'population': 274533527,
#    'total_pe_ct': 892000,
#    'agency_count_pe_submitting': 13275,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.25},
#   {'data_year': 1996,
#    'civilian_ct': 257790,
#    'female_civilian_ct': 160397,
#    'female_officer_ct': 66329,
#    'female_total_ct': 226726,
#    'male_civilian_ct': 97393,
#    'male_officer_ct': 591878,
#    'male_total_ct': 689271,
#    'population': 279987086,
#    'total_pe_ct': 915997,
#    'agency_count_pe_submitting': 12544,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.27},
#   {'data_year': 1997,
#    'civilian_ct': 251779,
#    'female_civilian_ct': 157165,
#    'female_officer_ct': 68048,
#    'female_total_ct': 225213,
#    'male_civilian_ct': 94614,
#    'male_officer_ct': 586901,
#    'male_total_ct': 681515,
#    'population': 279779640,
#    'total_pe_ct': 906728,
#    'agency_count_pe_submitting': 12906,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.24},
#   {'data_year': 1998,
#    'civilian_ct': 268863,
#    'female_civilian_ct': 167096,
#    'female_officer_ct': 71614,
#    'female_total_ct': 238710,
#    'male_civilian_ct': 101767,
#    'male_officer_ct': 607552,
#    'male_total_ct': 709319,
#    'population': 281772213,
#    'total_pe_ct': 948029,
#    'agency_count_pe_submitting': 12572,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.36},
#   {'data_year': 1999,
#    'civilian_ct': 287749,
#    'female_civilian_ct': 181552,
#    'female_officer_ct': 74386,
#    'female_total_ct': 255938,
#    'male_civilian_ct': 106197,
#    'male_officer_ct': 622750,
#    'male_total_ct': 728947,
#    'population': 286959578,
#    'total_pe_ct': 984885,
#    'agency_count_pe_submitting': 13220,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.43},
#   {'data_year': 2000,
#    'civilian_ct': 293528,
#    'female_civilian_ct': 183393,
#    'female_officer_ct': 76962,
#    'female_total_ct': 260355,
#    'male_civilian_ct': 110135,
#    'male_officer_ct': 630437,
#    'male_total_ct': 740572,
#    'population': 294295177,
#    'total_pe_ct': 1000927,
#    'agency_count_pe_submitting': 14033,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.4},
#   {'data_year': 2001,
#    'civilian_ct': 303670,
#    'female_civilian_ct': 189449,
#    'female_officer_ct': 80252,
#    'female_total_ct': 269701,
#    'male_civilian_ct': 114221,
#    'male_officer_ct': 639751,
#    'male_total_ct': 753972,
#    'population': 297245791,
#    'total_pe_ct': 1023673,
#    'agency_count_pe_submitting': 14123,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.44},
#   {'data_year': 2002,
#    'civilian_ct': 310777,
#    'female_civilian_ct': 192534,
#    'female_officer_ct': 80223,
#    'female_total_ct': 272757,
#    'male_civilian_ct': 118243,
#    'male_officer_ct': 637985,
#    'male_total_ct': 756228,
#    'population': 299620096,
#    'total_pe_ct': 1028985,
#    'agency_count_pe_submitting': 14776,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.43},
#   {'data_year': 2003,
#    'civilian_ct': 310434,
#    'female_civilian_ct': 192910,
#    'female_officer_ct': 82721,
#    'female_total_ct': 275631,
#    'male_civilian_ct': 117524,
#    'male_officer_ct': 645253,
#    'male_total_ct': 762777,
#    'population': 303677529,
#    'total_pe_ct': 1038408,
#    'agency_count_pe_submitting': 14882,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.42},
#   {'data_year': 2004,
#    'civilian_ct': 319538,
#    'female_civilian_ct': 197642,
#    'female_officer_ct': 85514,
#    'female_total_ct': 283156,
#    'male_civilian_ct': 121896,
#    'male_officer_ct': 653240,
#    'male_total_ct': 775136,
#    'population': 306481898,
#    'total_pe_ct': 1058292,
#    'agency_count_pe_submitting': 15299,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.45},
#   {'data_year': 2005,
#    'civilian_ct': 320864,
#    'female_civilian_ct': 197730,
#    'female_officer_ct': 85606,
#    'female_total_ct': 283336,
#    'male_civilian_ct': 123134,
#    'male_officer_ct': 651640,
#    'male_total_ct': 774774,
#    'population': 307251878,
#    'total_pe_ct': 1058110,
#    'agency_count_pe_submitting': 15435,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.44},
#   {'data_year': 2006,
#    'civilian_ct': 328015,
#    'female_civilian_ct': 201465,
#    'female_officer_ct': 87510,
#    'female_total_ct': 288975,
#    'male_civilian_ct': 126550,
#    'male_officer_ct': 660885,
#    'male_total_ct': 787435,
#    'population': 309434275,
#    'total_pe_ct': 1076410,
#    'agency_count_pe_submitting': 16060,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.48},
#   {'data_year': 2007,
#    'civilian_ct': 347467,
#    'female_civilian_ct': 211851,
#    'female_officer_ct': 88558,
#    'female_total_ct': 300409,
#    'male_civilian_ct': 135616,
#    'male_officer_ct': 672268,
#    'male_total_ct': 807884,
#    'population': 312284936,
#    'total_pe_ct': 1108293,
#    'agency_count_pe_submitting': 16321,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.55},
#   {'data_year': 2008,
#    'civilian_ct': 339878,
#    'female_civilian_ct': 208775,
#    'female_officer_ct': 90841,
#    'female_total_ct': 299616,
#    'male_civilian_ct': 131103,
#    'male_officer_ct': 681303,
#    'male_total_ct': 812406,
#    'population': 314905802,
#    'total_pe_ct': 1112022,
#    'agency_count_pe_submitting': 16458,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.53},
#   {'data_year': 2009,
#    'civilian_ct': 342433,
#    'female_civilian_ct': 208139,
#    'female_officer_ct': 93406,
#    'female_total_ct': 301545,
#    'male_civilian_ct': 134294,
#    'male_officer_ct': 694081,
#    'male_total_ct': 828375,
#    'population': 316298981,
#    'total_pe_ct': 1129920,
#    'agency_count_pe_submitting': 16636,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.57},
#   {'data_year': 2010,
#    'civilian_ct': 332837,
#    'female_civilian_ct': 202289,
#    'female_officer_ct': 90073,
#    'female_total_ct': 292362,
#    'male_civilian_ct': 130548,
#    'male_officer_ct': 676469,
#    'male_total_ct': 807017,
#    'population': 318512605,
#    'total_pe_ct': 1099379,
#    'agency_count_pe_submitting': 17342,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.45},
#   {'data_year': 2011,
#    'civilian_ct': 335398,
#    'female_civilian_ct': 203576,
#    'female_officer_ct': 103664,
#    'female_total_ct': 307240,
#    'male_civilian_ct': 131822,
#    'male_officer_ct': 690450,
#    'male_total_ct': 822272,
#    'population': 322276014,
#    'total_pe_ct': 1129512,
#    'agency_count_pe_submitting': 17298,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.5},
#   {'data_year': 2012,
#    'civilian_ct': 329648,
#    'female_civilian_ct': 197750,
#    'female_officer_ct': 92045,
#    'female_total_ct': 289795,
#    'male_civilian_ct': 131898,
#    'male_officer_ct': 680305,
#    'male_total_ct': 812203,
#    'population': 323754843,
#    'total_pe_ct': 1101998,
#    'agency_count_pe_submitting': 17248,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.4},
#   {'data_year': 2013,
#    'civilian_ct': 323950,
#    'female_civilian_ct': 196277,
#    'female_officer_ct': 90188,
#    'female_total_ct': 286465,
#    'male_civilian_ct': 127673,
#    'male_officer_ct': 678447,
#    'male_total_ct': 806120,
#    'population': 325359020,
#    'total_pe_ct': 1092585,
#    'agency_count_pe_submitting': 17490,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.36},
#   {'data_year': 2014,
#    'civilian_ct': 329792,
#    'female_civilian_ct': 197065,
#    'female_officer_ct': 91739,
#    'female_total_ct': 288804,
#    'male_civilian_ct': 132727,
#    'male_officer_ct': 678578,
#    'male_total_ct': 811305,
#    'population': 328133558,
#    'total_pe_ct': 1100109,
#    'agency_count_pe_submitting': 17439,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.35},
#   {'data_year': 2015,
#    'civilian_ct': 336473,
#    'female_civilian_ct': 201187,
#    'female_officer_ct': 93814,
#    'female_total_ct': 295001,
#    'male_civilian_ct': 135286,
#    'male_officer_ct': 697224,
#    'male_total_ct': 832510,
#    'population': 332627419,
#    'total_pe_ct': 1127511,
#    'agency_count_pe_submitting': 17502,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.39},
#   {'data_year': 2016,
#    'civilian_ct': 343554,
#    'female_civilian_ct': 205608,
#    'female_officer_ct': 95553,
#    'female_total_ct': 301161,
#    'male_civilian_ct': 137946,
#    'male_officer_ct': 697876,
#    'male_total_ct': 835822,
#    'population': 333934559,
#    'total_pe_ct': 1136983,
#    'agency_count_pe_submitting': 17547,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.4},
#   {'data_year': 2017,
#    'civilian_ct': 288516,
#    'female_civilian_ct': 174195,
#    'female_officer_ct': 84427,
#    'female_total_ct': 258622,
#    'male_civilian_ct': 114321,
#    'male_officer_ct': 591409,
#    'male_total_ct': 705730,
#    'population': 336664398,
#    'total_pe_ct': 964352,
#    'agency_count_pe_submitting': 16536,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.86},
#   {'data_year': 2018,
#    'civilian_ct': 296716,
#    'female_civilian_ct': 178993,
#    'female_officer_ct': 90939,
#    'female_total_ct': 269932,
#    'male_civilian_ct': 117723,
#    'male_officer_ct': 619525,
#    'male_total_ct': 737248,
#    'population': 339044592,
#    'total_pe_ct': 1007180,
#    'agency_count_pe_submitting': 16609,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.97}],
#  'pagination': {'count': 34, 'page': 0, 'pages': 1, 'per_page': 0}}

# %%
# State level UCR Estimated Crime data
AKCrime = f"{FBIurl}api/estimates/states/AK/1985/2018"
ALCrime = f"{FBIurl}api/estimates/states/AL/1985/2018"
ARCrime = f"{FBIurl}api/estimates/states/AR/1985/2018"
ASCrime = f"{FBIurl}api/estimates/states/AS/1985/2018"
AZCrime = f"{FBIurl}api/estimates/states/AZ/1985/2018"
CACrime = f"{FBIurl}api/estimates/states/CA/1985/2018"
COCrime = f"{FBIurl}api/estimates/states/CO/1985/2018"
CTCrime = f"{FBIurl}api/estimates/states/CT/1985/2018"
CZCrime = f"{FBIurl}api/estimates/states/CZ/1985/2018"
DCCrime = f"{FBIurl}api/estimates/states/DC/1985/2018"
DECrime = f"{FBIurl}api/estimates/states/DE/1985/2018"
FLCrime = f"{FBIurl}api/estimates/states/FL/1985/2018"
GACrime = f"{FBIurl}api/estimates/states/GA/1985/2018"
GMCrime = f"{FBIurl}api/estimates/states/GM/1985/2018"
HICrime = f"{FBIurl}api/estimates/states/HI/1985/2018"
IACrime = f"{FBIurl}api/estimates/states/IA/1985/2018"
IDCrime = f"{FBIurl}api/estimates/states/ID/1985/2018"
ILCrime = f"{FBIurl}api/estimates/states/IL/1985/2018"
INCrime = f"{FBIurl}api/estimates/states/IN/1985/2018"
KSCrime = f"{FBIurl}api/estimates/states/KS/1985/2018"
KYCrime = f"{FBIurl}api/estimates/states/KY/1985/2018"
LACrime = f"{FBIurl}api/estimates/states/LA/1985/2018"
MACrime = f"{FBIurl}api/estimates/states/MA/1985/2018"
MDCrime = f"{FBIurl}api/estimates/states/MD/1985/2018"
MECrime = f"{FBIurl}api/estimates/states/ME/1985/2018"
MICrime = f"{FBIurl}api/estimates/states/MI/1985/2018"
MNCrime = f"{FBIurl}api/estimates/states/MN/1985/2018"
MOCrime = f"{FBIurl}api/estimates/states/MO/1985/2018"
MSCrime = f"{FBIurl}api/estimates/states/MS/1985/2018"
MTCrime = f"{FBIurl}api/estimates/states/MT/1985/2018"
NCCrime = f"{FBIurl}api/estimates/states/NC/1985/2018"
NDCrime = f"{FBIurl}api/estimates/states/ND/1985/2018"
NECrime = f"{FBIurl}api/estimates/states/NE/1985/2018"
NHCrime = f"{FBIurl}api/estimates/states/NH/1985/2018"
NJCrime = f"{FBIurl}api/estimates/states/NJ/1985/2018"
NMCrime = f"{FBIurl}api/estimates/states/NM/1985/2018"
NVCrime = f"{FBIurl}api/estimates/states/NV/1985/2018"
NYCrime = f"{FBIurl}api/estimates/states/NY/1985/2018"
OHCrime = f"{FBIurl}api/estimates/states/OH/1985/2018"
OKCrime = f"{FBIurl}api/estimates/states/OK/1985/2018"
ORCrime = f"{FBIurl}api/estimates/states/OR/1985/2018"
PACrime = f"{FBIurl}api/estimates/states/PA/1985/2018"
RICrime = f"{FBIurl}api/estimates/states/RI/1985/2018"
SCCrime = f"{FBIurl}api/estimates/states/SC/1985/2018"
SDCrime = f"{FBIurl}api/estimates/states/SD/1985/2018"
TNCrime = f"{FBIurl}api/estimates/states/TN/1985/2018"
TXCrime = f"{FBIurl}api/estimates/states/TX/1985/2018"
UTCrime = f"{FBIurl}api/estimates/states/UT/1985/2018"
VACrime = f"{FBIurl}api/estimates/states/VA/1985/2018"
VTCrime = f"{FBIurl}api/estimates/states/VT/1985/2018"
WACrime = f"{FBIurl}api/estimates/states/WA/1985/2018"
WICrime = f"{FBIurl}api/estimates/states/WI/1985/2018"
WVCrime = f"{FBIurl}api/estimates/states/WU/1985/2018"
WYCrime = f"{FBIurl}api/estimates/states/WY/1985/2018"
PRCrime = f"{FBIurl}api/estimates/states/PR/1985/2018"
MPCrime = f"{FBIurl}api/estimates/states/MP/1985/2018"
OTCrime = f"{FBIurl}api/estimates/states/OT/1985/2018"
VICrime = f"{FBIurl}api/estimates/states/VI/1985/2018"
# Base Url
AKCrimeUrl = f"{AKCrime}?api_key={datagov_key}"
ALCrimeUrl = f"{ALCrime}?api_key={datagov_key}"
ARCrimeUrl = f"{ARCrime}?api_key={datagov_key}"
ASCrimeUrl = f"{ASCrime}?api_key={datagov_key}"
AZCrimeUrl = f"{AZCrime}?api_key={datagov_key}"
CACrimeUrl = f"{CACrime}?api_key={datagov_key}"
COCrimeUrl = f"{COCrime}?api_key={datagov_key}"
CTCrimeUrl = f"{CTCrime}?api_key={datagov_key}"
CZCrimeUrl = f"{CZCrime}?api_key={datagov_key}"
DCCrimeUrl = f"{DCCrime}?api_key={datagov_key}"
DECrimeUrl = f"{DECrime}?api_key={datagov_key}"
FLCrimeUrl = f"{FLCrime}?api_key={datagov_key}"
GACrimeUrl = f"{GACrime}?api_key={datagov_key}"
GMCrimeUrl = f"{GMCrime}?api_key={datagov_key}"
HICrimeUrl = f"{HICrime}?api_key={datagov_key}"
IACrimeUrl = f"{IACrime}?api_key={datagov_key}"
IDCrimeUrl = f"{IDCrime}?api_key={datagov_key}"
ILCrimeUrl = f"{ILCrime}?api_key={datagov_key}"
INCrimeUrl = f"{INCrime}?api_key={datagov_key}"
KSCrimeUrl = f"{KSCrime}?api_key={datagov_key}"
KYCrimeUrl = f"{KYCrime}?api_key={datagov_key}"
LACrimeUrl = f"{LACrime}?api_key={datagov_key}"
MACrimeUrl = f"{MACrime}?api_key={datagov_key}"
MDCrimeUrl = f"{MDCrime}?api_key={datagov_key}"
MECrimeUrl = f"{MECrime}?api_key={datagov_key}"
MICrimeUrl = f"{MICrime}?api_key={datagov_key}"
MNCrimeUrl = f"{MNCrime}?api_key={datagov_key}"
MOCrimeUrl = f"{MOCrime}?api_key={datagov_key}"
MSCrimeUrl = f"{MSCrime}?api_key={datagov_key}"
MTCrimeUrl = f"{MTCrime}?api_key={datagov_key}"
NCCrimeUrl = f"{NCCrime}?api_key={datagov_key}"
NDCrimeUrl = f"{NDCrime}?api_key={datagov_key}"
NECrimeUrl = f"{NECrime}?api_key={datagov_key}"
NHCrimeUrl = f"{NHCrime}?api_key={datagov_key}"
NJCrimeUrl = f"{NJCrime}?api_key={datagov_key}"
NMCrimeUrl = f"{NMCrime}?api_key={datagov_key}"
NVCrimeUrl = f"{NVCrime}?api_key={datagov_key}"
NYCrimeUrl = f"{NYCrime}?api_key={datagov_key}"
OHCrimeUrl = f"{OHCrime}?api_key={datagov_key}"
OKCrimeUrl = f"{OKCrime}?api_key={datagov_key}"
ORCrimeUrl = f"{ORCrime}?api_key={datagov_key}"
PACrimeUrl = f"{PACrime}?api_key={datagov_key}"
RICrimeUrl = f"{RICrime}?api_key={datagov_key}"
SCCrimeUrl = f"{SCCrime}?api_key={datagov_key}"
SDCrimeUrl = f"{SDCrime}?api_key={datagov_key}"
TNCrimeUrl = f"{TNCrime}?api_key={datagov_key}"
TXCrimeUrl = f"{TXCrime}?api_key={datagov_key}"
UTCrimeUrl = f"{UTCrime}?api_key={datagov_key}"
VACrimeUrl = f"{VACrime}?api_key={datagov_key}"
VTCrimeUrl = f"{VTCrime}?api_key={datagov_key}"
WACrimeUrl = f"{WACrime}?api_key={datagov_key}"
WICrimeUrl = f"{WICrime}?api_key={datagov_key}"
WVCrimeUrl = f"{WVCrime}?api_key={datagov_key}"
WYCrimeUrl = f"{WYCrime}?api_key={datagov_key}"
PRCrimeUrl = f"{PRCrime}?api_key={datagov_key}"
MPCrimeUrl = f"{MPCrime}?api_key={datagov_key}"
OTCrimeUrl = f"{OTCrime}?api_key={datagov_key}"
VICrimeUrl = f"{VICrime}?api_key={datagov_key}"
# Retrieve data and convert to json
AKstateCrime = requests.get(AKCrimeUrl).json()
ALstateCrime = requests.get(ALCrimeUrl).json()
ARstateCrime = requests.get(ARCrimeUrl).json()
ASstateCrime = requests.get(ASCrimeUrl).json()
AZstateCrime = requests.get(AZCrimeUrl).json()
CAstateCrime = requests.get(CACrimeUrl).json()
COstateCrime = requests.get(COCrimeUrl).json()
CTstateCrime = requests.get(CTCrimeUrl).json()
CZstateCrime = requests.get(CZCrimeUrl).json()
DCstateCrime = requests.get(DCCrimeUrl).json()
DEstateCrime = requests.get(DECrimeUrl).json()
FLstateCrime = requests.get(FLCrimeUrl).json()
GAstateCrime = requests.get(GACrimeUrl).json()
GMstateCrime = requests.get(GMCrimeUrl).json()
HIstateCrime = requests.get(HICrimeUrl).json()
IAstateCrime = requests.get(IACrimeUrl).json()
IDstateCrime = requests.get(IDCrimeUrl).json()
ILstateCrime = requests.get(ILCrimeUrl).json()
INstateCrime = requests.get(INCrimeUrl).json()
KSstateCrime = requests.get(KSCrimeUrl).json()
KYstateCrime = requests.get(KYCrimeUrl).json()
LAstateCrime = requests.get(LACrimeUrl).json()
MAstateCrime = requests.get(MACrimeUrl).json()
MDstateCrime = requests.get(MDCrimeUrl).json()
MEstateCrime = requests.get(MECrimeUrl).json()
MIstateCrime = requests.get(MICrimeUrl).json()
MNstateCrime = requests.get(MNCrimeUrl).json()
MOstateCrime = requests.get(MOCrimeUrl).json()
MSstateCrime = requests.get(MSCrimeUrl).json()
MTstateCrime = requests.get(MTCrimeUrl).json()
NCstateCrime = requests.get(NCCrimeUrl).json()
NDstateCrime = requests.get(NDCrimeUrl).json()
NEstateCrime = requests.get(NECrimeUrl).json()
NHstateCrime = requests.get(NHCrimeUrl).json()
NJstateCrime = requests.get(NJCrimeUrl).json()
NMstateCrime = requests.get(NMCrimeUrl).json()
NVstateCrime = requests.get(NVCrimeUrl).json()
NYstateCrime = requests.get(NYCrimeUrl).json()
OHstateCrime = requests.get(OHCrimeUrl).json()
OKstateCrime = requests.get(OKCrimeUrl).json()
ORstateCrime = requests.get(ORCrimeUrl).json()
PAstateCrime = requests.get(PACrimeUrl).json()
RIstateCrime = requests.get(RICrimeUrl).json()
SCstateCrime = requests.get(SCCrimeUrl).json()
SDstateCrime = requests.get(SDCrimeUrl).json()
TNstateCrime = requests.get(TNCrimeUrl).json()
TXstateCrime = requests.get(TXCrimeUrl).json()
UTstateCrime = requests.get(UTCrimeUrl).json()
VAstateCrime = requests.get(VACrimeUrl).json()
VTstateCrime = requests.get(VTCrimeUrl).json()
WAstateCrime = requests.get(WACrimeUrl).json()
WIstateCrime = requests.get(WICrimeUrl).json()
WVstateCrime = requests.get(WVCrimeUrl).json()
WYstateCrime = requests.get(WYCrimeUrl).json()
PRstateCrime = requests.get(PRCrimeUrl).json()
MPstateCrime = requests.get(MPCrimeUrl).json()
OTstateCrime = requests.get(OTCrimeUrl).json()
VIstateCrime = requests.get(VICrimeUrl).json()
# Out:
# {'results': [{'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2004,
#    'population': 657755,
#    'violent_crime': 4159,
#    'homicide': 37,
#    'rape_legacy': 558,
#    'rape_revised': None,
#    'robbery': 447,
#    'aggravated_assault': 3117,
#    'property_crime': 22172,
#    'burglary': 3773,
#    'larceny': 16159,
#    'motor_vehicle_theft': 2240,
#    'arson': 180},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2005,
#    'population': 663253,
#    'violent_crime': 4194,
#    'homicide': 32,
#    'rape_legacy': 538,
#    'rape_revised': None,
#    'robbery': 537,
#    'aggravated_assault': 3087,
#    'property_crime': 23975,
#    'burglary': 4131,
#    'larceny': 17249,
#    'motor_vehicle_theft': 2595,
#    'arson': 159},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2006,
#    'population': 670053,
#    'violent_crime': 4610,
#    'homicide': 36,
#    'rape_legacy': 512,
#    'rape_revised': None,
#    'robbery': 600,
#    'aggravated_assault': 3462,
#    'property_crime': 23975,
#    'burglary': 4155,
#    'larceny': 17284,
#    'motor_vehicle_theft': 2536,
#    'arson': 221},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2007,
#    'population': 683478,
#    'violent_crime': 4520,
#    'homicide': 43,
#    'rape_legacy': 545,
#    'rape_revised': None,
#    'robbery': 581,
#    'aggravated_assault': 3351,
#    'property_crime': 23096,
#    'burglary': 3734,
#    'larceny': 16929,
#    'motor_vehicle_theft': 2433,
#    'arson': 263},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2008,
#    'population': 686293,
#    'violent_crime': 4475,
#    'homicide': 27,
#    'rape_legacy': 447,
#    'rape_revised': None,
#    'robbery': 645,
#    'aggravated_assault': 3356,
#    'property_crime': 20090,
#    'burglary': 3237,
#    'larceny': 15225,
#    'motor_vehicle_theft': 1628,
#    'arson': 167},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2009,
#    'population': 698473,
#    'violent_crime': 4424,
#    'homicide': 22,
#    'rape_legacy': 513,
#    'rape_revised': None,
#    'robbery': 654,
#    'aggravated_assault': 3235,
#    'property_crime': 20538,
#    'burglary': 3600,
#    'larceny': 15251,
#    'motor_vehicle_theft': 1687,
#    'arson': 190},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2010,
#    'population': 714146,
#    'violent_crime': 4537,
#    'homicide': 31,
#    'rape_legacy': 533,
#    'rape_revised': None,
#    'robbery': 594,
#    'aggravated_assault': 3379,
#    'property_crime': 20259,
#    'burglary': 3105,
#    'larceny': 15535,
#    'motor_vehicle_theft': 1619,
#    'arson': 178},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2016,
#    'population': 741522,
#    'violent_crime': 5966,
#    'homicide': 52,
#    'rape_legacy': 1053,
#    'rape_revised': 1053,
#    'robbery': 850,
#    'aggravated_assault': 4011,
#    'property_crime': 24876,
#    'burglary': 4053,
#    'larceny': 17766,
#    'motor_vehicle_theft': 3057,
#    'arson': 144},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2011,
#    'population': 723860,
#    'violent_crime': 4416,
#    'homicide': 30,
#    'rape_legacy': 436,
#    'rape_revised': None,
#    'robbery': 576,
#    'aggravated_assault': 3374,
#    'property_crime': 19094,
#    'burglary': 2852,
#    'larceny': 14854,
#    'motor_vehicle_theft': 1388,
#    'arson': 222},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1995,
#    'population': 604000,
#    'violent_crime': 4656,
#    'homicide': 55,
#    'rape_legacy': 485,
#    'rape_revised': None,
#    'robbery': 937,
#    'aggravated_assault': 3179,
#    'property_crime': 30097,
#    'burglary': 5055,
#    'larceny': 21891,
#    'motor_vehicle_theft': 3151,
#    'arson': 237},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2012,
#    'population': 730307,
#    'violent_crime': 4412,
#    'homicide': 30,
#    'rape_legacy': 583,
#    'rape_revised': None,
#    'robbery': 630,
#    'aggravated_assault': 3169,
#    'property_crime': 20037,
#    'burglary': 2950,
#    'larceny': 15565,
#    'motor_vehicle_theft': 1522,
#    'arson': 187},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2015,
#    'population': 737709,
#    'violent_crime': 5391,
#    'homicide': 59,
#    'rape_legacy': 648,
#    'rape_revised': 900,
#    'robbery': 761,
#    'aggravated_assault': 3671,
#    'property_crime': 20806,
#    'burglary': 3511,
#    'larceny': 15249,
#    'motor_vehicle_theft': 2046,
#    'arson': 182},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2013,
#    'population': 737259,
#    'violent_crime': 4709,
#    'homicide': 34,
#    'rape_legacy': 657,
#    'rape_revised': 925,
#    'robbery': 623,
#    'aggravated_assault': 3127,
#    'property_crime': 21211,
#    'burglary': 2917,
#    'larceny': 16599,
#    'motor_vehicle_theft': 1695,
#    'arson': 154},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2014,
#    'population': 737046,
#    'violent_crime': 4684,
#    'homicide': 41,
#    'rape_legacy': 553,
#    'rape_revised': 771,
#    'robbery': 629,
#    'aggravated_assault': 3243,
#    'property_crime': 20334,
#    'burglary': 3150,
#    'larceny': 15445,
#    'motor_vehicle_theft': 1739,
#    'arson': 145},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1979,
#    'population': 406000,
#    'violent_crime': 1994,
#    'homicide': 54,
#    'rape_legacy': 292,
#    'rape_revised': None,
#    'robbery': 445,
#    'aggravated_assault': 1203,
#    'property_crime': 23193,
#    'burglary': 5616,
#    'larceny': 15076,
#    'motor_vehicle_theft': 2501,
#    'arson': None},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1980,
#    'population': 440142,
#    'violent_crime': 1919,
#    'homicide': 39,
#    'rape_legacy': 250,
#    'rape_revised': None,
#    'robbery': 360,
#    'aggravated_assault': 1270,
#    'property_crime': 22930,
#    'burglary': 5545,
#    'larceny': 14916,
#    'motor_vehicle_theft': 2469,
#    'arson': None},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1981,
#    'population': 412000,
#    'violent_crime': 2537,
#    'homicide': 60,
#    'rape_legacy': 421,
#    'rape_revised': None,
#    'robbery': 472,
#    'aggravated_assault': 1584,
#    'property_crime': 24634,
#    'burglary': 5479,
#    'larceny': 16310,
#    'motor_vehicle_theft': 2845,
#    'arson': None},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1982,
#    'population': 438000,
#    'violent_crime': 2732,
#    'homicide': 81,
#    'rape_legacy': 374,
#    'rape_revised': None,
#    'robbery': 586,
#    'aggravated_assault': 1691,
#    'property_crime': 24479,
#    'burglary': 5204,
#    'larceny': 16672,
#    'motor_vehicle_theft': 2603,
#    'arson': None},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1983,
#    'population': 479000,
#    'violent_crime': 2940,
#    'homicide': 66,
#    'rape_legacy': 486,
#    'rape_revised': None,
#    'robbery': 465,
#    'aggravated_assault': 1923,
#    'property_crime': 25889,
#    'burglary': 5720,
#    'larceny': 17085,
#    'motor_vehicle_theft': 3084,
#    'arson': None},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1984,
#    'population': 500000,
#    'violent_crime': 3108,
#    'homicide': 58,
#    'rape_legacy': 458,
#    'rape_revised': None,
#    'robbery': 547,
#    'aggravated_assault': 2045,
#    'property_crime': 27468,
#    'burglary': 6184,
#    'larceny': 18140,
#    'motor_vehicle_theft': 3144,
#    'arson': None},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1985,
#    'population': 521000,
#    'violent_crime': 3031,
#    'homicide': 51,
#    'rape_legacy': 402,
#    'rape_revised': None,
#    'robbery': 484,
#    'aggravated_assault': 2094,
#    'property_crime': 27588,
#    'burglary': 6209,
#    'larceny': 18220,
#    'motor_vehicle_theft': 3159,
#    'arson': 276},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1986,
#    'population': 534000,
#    'violent_crime': 3046,
#    'homicide': 46,
#    'rape_legacy': 388,
#    'rape_revised': None,
#    'robbery': 470,
#    'aggravated_assault': 2142,
#    'property_crime': 30307,
#    'burglary': 6204,
#    'larceny': 20879,
#    'motor_vehicle_theft': 3224,
#    'arson': 237},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1987,
#    'population': 525000,
#    'violent_crime': 2391,
#    'homicide': 53,
#    'rape_legacy': 341,
#    'rape_revised': None,
#    'robbery': 384,
#    'aggravated_assault': 1613,
#    'property_crime': 25841,
#    'burglary': 5093,
#    'larceny': 18195,
#    'motor_vehicle_theft': 2553,
#    'arson': 324},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1988,
#    'population': 513000,
#    'violent_crime': 2682,
#    'homicide': 29,
#    'rape_legacy': 296,
#    'rape_revised': None,
#    'robbery': 374,
#    'aggravated_assault': 1983,
#    'property_crime': 22566,
#    'burglary': 4321,
#    'larceny': 15911,
#    'motor_vehicle_theft': 2334,
#    'arson': 119},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1989,
#    'population': 527000,
#    'violent_crime': 2623,
#    'homicide': 42,
#    'rape_legacy': 279,
#    'rape_revised': None,
#    'robbery': 356,
#    'aggravated_assault': 1946,
#    'property_crime': 22567,
#    'burglary': 4358,
#    'larceny': 15811,
#    'motor_vehicle_theft': 2398,
#    'arson': 59},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1990,
#    'population': 550043,
#    'violent_crime': 2885,
#    'homicide': 41,
#    'rape_legacy': 401,
#    'rape_revised': None,
#    'robbery': 422,
#    'aggravated_assault': 2021,
#    'property_crime': 25457,
#    'burglary': 4919,
#    'larceny': 17428,
#    'motor_vehicle_theft': 3110,
#    'arson': 187},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1991,
#    'population': 570000,
#    'violent_crime': 3499,
#    'homicide': 42,
#    'rape_legacy': 523,
#    'rape_revised': None,
#    'robbery': 645,
#    'aggravated_assault': 2289,
#    'property_crime': 29000,
#    'burglary': 5582,
#    'larceny': 20375,
#    'motor_vehicle_theft': 3043,
#    'arson': 203},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1992,
#    'population': 587000,
#    'violent_crime': 3877,
#    'homicide': 44,
#    'rape_legacy': 579,
#    'rape_revised': None,
#    'robbery': 640,
#    'aggravated_assault': 2614,
#    'property_crime': 28816,
#    'burglary': 5170,
#    'larceny': 20728,
#    'motor_vehicle_theft': 2918,
#    'arson': 198},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1993,
#    'population': 599000,
#    'violent_crime': 4557,
#    'homicide': 54,
#    'rape_legacy': 502,
#    'rape_revised': None,
#    'robbery': 733,
#    'aggravated_assault': 3268,
#    'property_crime': 28795,
#    'burglary': 4893,
#    'larceny': 21201,
#    'motor_vehicle_theft': 2701,
#    'arson': 217},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1994,
#    'population': 606000,
#    'violent_crime': 4644,
#    'homicide': 38,
#    'rape_legacy': 418,
#    'rape_revised': None,
#    'robbery': 886,
#    'aggravated_assault': 3302,
#    'property_crime': 29947,
#    'burglary': 4848,
#    'larceny': 21824,
#    'motor_vehicle_theft': 3275,
#    'arson': 275},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2017,
#    'population': 739786,
#    'violent_crime': 6338,
#    'homicide': 62,
#    'rape_legacy': None,
#    'rape_revised': 1074,
#    'robbery': 952,
#    'aggravated_assault': 4250,
#    'property_crime': 26203,
#    'burglary': 4167,
#    'larceny': 17782,
#    'motor_vehicle_theft': 4254,
#    'arson': 139},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2018,
#    'population': 737438,
#    'violent_crime': 6526,
#    'homicide': 47,
#    'rape_legacy': None,
#    'rape_revised': 1192,
#    'robbery': 896,
#    'aggravated_assault': 4391,
#    'property_crime': 24339,
#    'burglary': 3979,
#    'larceny': 16364,
#    'motor_vehicle_theft': 3996,
#    'arson': 127},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1996,
#    'population': 607000,
#    'violent_crime': 4417,
#    'homicide': 45,
#    'rape_legacy': 398,
#    'rape_revised': None,
#    'robbery': 710,
#    'aggravated_assault': 3264,
#    'property_crime': 28667,
#    'burglary': 5118,
#    'larceny': 20557,
#    'motor_vehicle_theft': 2992,
#    'arson': 179},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1997,
#    'population': 609000,
#    'violent_crime': 4270,
#    'homicide': 54,
#    'rape_legacy': 403,
#    'rape_revised': None,
#    'robbery': 648,
#    'aggravated_assault': 3165,
#    'property_crime': 27840,
#    'burglary': 4276,
#    'larceny': 20780,
#    'motor_vehicle_theft': 2784,
#    'arson': 174},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1998,
#    'population': 614000,
#    'violent_crime': 4015,
#    'homicide': 41,
#    'rape_legacy': 421,
#    'rape_revised': None,
#    'robbery': 532,
#    'aggravated_assault': 3021,
#    'property_crime': 25316,
#    'burglary': 4098,
#    'larceny': 18611,
#    'motor_vehicle_theft': 2607,
#    'arson': 178},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 1999,
#    'population': 619500,
#    'violent_crime': 3908,
#    'homicide': 52,
#    'rape_legacy': 517,
#    'rape_revised': None,
#    'robbery': 566,
#    'aggravated_assault': 2773,
#    'property_crime': 23099,
#    'burglary': 3787,
#    'larceny': 16654,
#    'motor_vehicle_theft': 2658,
#    'arson': 181},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2000,
#    'population': 626932,
#    'violent_crime': 3554,
#    'homicide': 27,
#    'rape_legacy': 497,
#    'rape_revised': None,
#    'robbery': 490,
#    'aggravated_assault': 2540,
#    'property_crime': 23087,
#    'burglary': 3899,
#    'larceny': 16838,
#    'motor_vehicle_theft': 2350,
#    'arson': 202},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2001,
#    'population': 633630,
#    'violent_crime': 3735,
#    'homicide': 39,
#    'rape_legacy': 501,
#    'rape_revised': None,
#    'robbery': 514,
#    'aggravated_assault': 2681,
#    'property_crime': 23160,
#    'burglary': 3847,
#    'larceny': 16695,
#    'motor_vehicle_theft': 2618,
#    'arson': 225},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2002,
#    'population': 641482,
#    'violent_crime': 3627,
#    'homicide': 33,
#    'rape_legacy': 511,
#    'rape_revised': None,
#    'robbery': 489,
#    'aggravated_assault': 2594,
#    'property_crime': 24118,
#    'burglary': 3908,
#    'larceny': 17739,
#    'motor_vehicle_theft': 2471,
#    'arson': 245},
#   {'state_id': 1,
#    'state_abbr': 'AK',
#    'year': 2003,
#    'population': 648280,
#    'violent_crime': 3877,
#    'homicide': 39,
#    'rape_legacy': 605,
#    'rape_revised': None,
#    'robbery': 446,
#    'aggravated_assault': 2787,
#    'property_crime': 24386,
#    'burglary': 3874,
#    'larceny': 18051,
#    'motor_vehicle_theft': 2461,
#    'arson': 252}],
#  'pagination': {'count': 40, 'page': 0, 'pages': 1, 'per_page': 0}}

# %%
# State level Arrest Demographic data
AKArrest = f"{FBIurl}api/arrest/states/offense/AK/all/1985/2018"
ALArrest = f"{FBIurl}api/arrest/states/offense/AL/all/1985/2018"
ARArrest = f"{FBIurl}api/arrest/states/offense/AR/all/1985/2018"
ASArrest = f"{FBIurl}api/arrest/states/offense/AS/all/1985/2018"
AZArrest = f"{FBIurl}api/arrest/states/offense/AZ/all/1985/2018"
CAArrest = f"{FBIurl}api/arrest/states/offense/CA/all/1985/2018"
COArrest = f"{FBIurl}api/arrest/states/offense/CO/all/1985/2018"
CTArrest = f"{FBIurl}api/arrest/states/offense/CT/all/1985/2018"
CZArrest = f"{FBIurl}api/arrest/states/offense/CZ/all/1985/2018"
DCArrest = f"{FBIurl}api/arrest/states/offense/DC/all/1985/2018"
DEArrest = f"{FBIurl}api/arrest/states/offense/DE/all/1985/2018"
FLArrest = f"{FBIurl}api/arrest/states/offense/FL/all/1985/2018"
GAArrest = f"{FBIurl}api/arrest/states/offense/GA/all/1985/2018"
GMArrest = f"{FBIurl}api/arrest/states/offense/GM/all/1985/2018"
HIArrest = f"{FBIurl}api/arrest/states/offense/HI/all/1985/2018"
IAArrest = f"{FBIurl}api/arrest/states/offense/IA/all/1985/2018"
IDArrest = f"{FBIurl}api/arrest/states/offense/ID/all/1985/2018"
ILArrest = f"{FBIurl}api/arrest/states/offense/IL/all/1985/2018"
INArrest = f"{FBIurl}api/arrest/states/offense/IN/all/1985/2018"
KSArrest = f"{FBIurl}api/arrest/states/offense/KS/all/1985/2018"
KYArrest = f"{FBIurl}api/arrest/states/offense/KY/all/1985/2018"
LAArrest = f"{FBIurl}api/arrest/states/offense/LA/all/1985/2018"
MAArrest = f"{FBIurl}api/arrest/states/offense/MA/all/1985/2018"
MDArrest = f"{FBIurl}api/arrest/states/offense/MD/all/1985/2018"
MEArrest = f"{FBIurl}api/arrest/states/offense/ME/all/1985/2018"
MIArrest = f"{FBIurl}api/arrest/states/offense/MI/all/1985/2018"
MNArrest = f"{FBIurl}api/arrest/states/offense/MN/all/1985/2018"
MOArrest = f"{FBIurl}api/arrest/states/offense/MO/all/1985/2018"
MSArrest = f"{FBIurl}api/arrest/states/offense/MS/all/1985/2018"
MTArrest = f"{FBIurl}api/arrest/states/offense/MT/all/1985/2018"
NCArrest = f"{FBIurl}api/arrest/states/offense/NC/all/1985/2018"
NDArrest = f"{FBIurl}api/arrest/states/offense/ND/all/1985/2018"
NEArrest = f"{FBIurl}api/arrest/states/offense/NE/all/1985/2018"
NHArrest = f"{FBIurl}api/arrest/states/offense/NH/all/1985/2018"
NJArrest = f"{FBIurl}api/arrest/states/offense/NJ/all/1985/2018"
NMArrest = f"{FBIurl}api/arrest/states/offense/NM/all/1985/2018"
NVArrest = f"{FBIurl}api/arrest/states/offense/NV/all/1985/2018"
NYArrest = f"{FBIurl}api/arrest/states/offense/NY/all/1985/2018"
OHArrest = f"{FBIurl}api/arrest/states/offense/OH/all/1985/2018"
OKArrest = f"{FBIurl}api/arrest/states/offense/OK/all/1985/2018"
ORArrest = f"{FBIurl}api/arrest/states/offense/OR/all/1985/2018"
PAArrest = f"{FBIurl}api/arrest/states/offense/PA/all/1985/2018"
RIArrest = f"{FBIurl}api/arrest/states/offense/RI/all/1985/2018"
SCArrest = f"{FBIurl}api/arrest/states/offense/SC/all/1985/2018"
SDArrest = f"{FBIurl}api/arrest/states/offense/SD/all/1985/2018"
TNArrest = f"{FBIurl}api/arrest/states/offense/TN/all/1985/2018"
TXArrest = f"{FBIurl}api/arrest/states/offense/TX/all/1985/2018"
UTArrest = f"{FBIurl}api/arrest/states/offense/UT/all/1985/2018"
VAArrest = f"{FBIurl}api/arrest/states/offense/VA/all/1985/2018"
VTArrest = f"{FBIurl}api/arrest/states/offense/VT/all/1985/2018"
WAArrest = f"{FBIurl}api/arrest/states/offense/WA/all/1985/2018"
WIArrest = f"{FBIurl}api/arrest/states/offense/WI/all/1985/2018"
WVArrest = f"{FBIurl}api/arrest/states/offense/WV/all/1985/2018"
WYArrest = f"{FBIurl}api/arrest/states/offense/WY/all/1985/2018"
PRArrest = f"{FBIurl}api/arrest/states/offense/PR/all/1985/2018"
MPArrest = f"{FBIurl}api/arrest/states/offense/MP/all/1985/2018"
OTArrest = f"{FBIurl}api/arrest/states/offense/OT/all/1985/2018"
VIArrest = f"{FBIurl}api/arrest/states/offense/VI/all/1985/2018"
# Base Url
AKArrestUrl = f"{AKArrest}?api_key={datagov_key}"
ALArrestUrl = f"{ALArrest}?api_key={datagov_key}"
ARArrestUrl = f"{ARArrest}?api_key={datagov_key}"
ASArrestUrl = f"{ASArrest}?api_key={datagov_key}"
AZArrestUrl = f"{AZArrest}?api_key={datagov_key}"
CAArrestUrl = f"{CAArrest}?api_key={datagov_key}"
COArrestUrl = f"{COArrest}?api_key={datagov_key}"
CTArrestUrl = f"{CTArrest}?api_key={datagov_key}"
CZArrestUrl = f"{CZArrest}?api_key={datagov_key}"
DCArrestUrl = f"{DCArrest}?api_key={datagov_key}"
DEArrestUrl = f"{DEArrest}?api_key={datagov_key}"
FLArrestUrl = f"{FLArrest}?api_key={datagov_key}"
GAArrestUrl = f"{GAArrest}?api_key={datagov_key}"
GMArrestUrl = f"{GMArrest}?api_key={datagov_key}"
HIArrestUrl = f"{HIArrest}?api_key={datagov_key}"
IAArrestUrl = f"{IAArrest}?api_key={datagov_key}"
IDArrestUrl = f"{IDArrest}?api_key={datagov_key}"
ILArrestUrl = f"{ILArrest}?api_key={datagov_key}"
INArrestUrl = f"{INArrest}?api_key={datagov_key}"
KSArrestUrl = f"{KSArrest}?api_key={datagov_key}"
KYArrestUrl = f"{KYArrest}?api_key={datagov_key}"
LAArrestUrl = f"{LAArrest}?api_key={datagov_key}"
MAArrestUrl = f"{MAArrest}?api_key={datagov_key}"
MDArrestUrl = f"{MDArrest}?api_key={datagov_key}"
MEArrestUrl = f"{MEArrest}?api_key={datagov_key}"
MIArrestUrl = f"{MIArrest}?api_key={datagov_key}"
MNArrestUrl = f"{MNArrest}?api_key={datagov_key}"
MOArrestUrl = f"{MOArrest}?api_key={datagov_key}"
MSArrestUrl = f"{MSArrest}?api_key={datagov_key}"
MTArrestUrl = f"{MTArrest}?api_key={datagov_key}"
NCArrestUrl = f"{NCArrest}?api_key={datagov_key}"
NDArrestUrl = f"{NDArrest}?api_key={datagov_key}"
NEArrestUrl = f"{NEArrest}?api_key={datagov_key}"
NHArrestUrl = f"{NHArrest}?api_key={datagov_key}"
NJArrestUrl = f"{NJArrest}?api_key={datagov_key}"
NMArrestUrl = f"{NMArrest}?api_key={datagov_key}"
NVArrestUrl = f"{NVArrest}?api_key={datagov_key}"
NYArrestUrl = f"{NYArrest}?api_key={datagov_key}"
OHArrestUrl = f"{OHArrest}?api_key={datagov_key}"
OKArrestUrl = f"{OKArrest}?api_key={datagov_key}"
ORArrestUrl = f"{ORArrest}?api_key={datagov_key}"
PAArrestUrl = f"{PAArrest}?api_key={datagov_key}"
RIArrestUrl = f"{RIArrest}?api_key={datagov_key}"
SCArrestUrl = f"{SCArrest}?api_key={datagov_key}"
SDArrestUrl = f"{SDArrest}?api_key={datagov_key}"
TNArrestUrl = f"{TNArrest}?api_key={datagov_key}"
TXArrestUrl = f"{TXArrest}?api_key={datagov_key}"
UTArrestUrl = f"{UTArrest}?api_key={datagov_key}"
VAArrestUrl = f"{VAArrest}?api_key={datagov_key}"
VTArrestUrl = f"{VTArrest}?api_key={datagov_key}"
WAArrestUrl = f"{WAArrest}?api_key={datagov_key}"
WIArrestUrl = f"{WIArrest}?api_key={datagov_key}"
WVArrestUrl = f"{WVArrest}?api_key={datagov_key}"
WYArrestUrl = f"{WYArrest}?api_key={datagov_key}"
PRArrestUrl = f"{PRArrest}?api_key={datagov_key}"
MPArrestUrl = f"{MPArrest}?api_key={datagov_key}"
OTArrestUrl = f"{OTArrest}?api_key={datagov_key}"
VIArrestUrl = f"{VIArrest}?api_key={datagov_key}"
# Retrieve data and convert to json
AKstateArrest = requests.get(AKArrestUrl).json()
ALstateArrest = requests.get(ALArrestUrl).json()
ARstateArrest = requests.get(ARArrestUrl).json()
ASstateArrest = requests.get(ASArrestUrl).json()
AZstateArrest = requests.get(AZArrestUrl).json()
CAstateArrest = requests.get(CAArrestUrl).json()
COstateArrest = requests.get(COArrestUrl).json()
CTstateArrest = requests.get(CTArrestUrl).json()
CZstateArrest = requests.get(CZArrestUrl).json()
DCstateArrest = requests.get(DCArrestUrl).json()
DEstateArrest = requests.get(DEArrestUrl).json()
FLstateArrest = requests.get(FLArrestUrl).json()
GAstateArrest = requests.get(GAArrestUrl).json()
GMstateArrest = requests.get(GMArrestUrl).json()
HIstateArrest = requests.get(HIArrestUrl).json()
IAstateArrest = requests.get(IAArrestUrl).json()
IDstateArrest = requests.get(IDArrestUrl).json()
ILstateArrest = requests.get(ILArrestUrl).json()
INstateArrest = requests.get(INArrestUrl).json()
KSstateArrest = requests.get(KSArrestUrl).json()
KYstateArrest = requests.get(KYArrestUrl).json()
LAstateArrest = requests.get(LAArrestUrl).json()
MAstateArrest = requests.get(MAArrestUrl).json()
MDstateArrest = requests.get(MDArrestUrl).json()
MEstateArrest = requests.get(MEArrestUrl).json()
MIstateArrest = requests.get(MIArrestUrl).json()
MNstateArrest = requests.get(MNArrestUrl).json()
MOstateArrest = requests.get(MOArrestUrl).json()
MSstateArrest = requests.get(MSArrestUrl).json()
MTstateArrest = requests.get(MTArrestUrl).json()
NCstateArrest = requests.get(NCArrestUrl).json()
NDstateArrest = requests.get(NDArrestUrl).json()
NEstateArrest = requests.get(NEArrestUrl).json()
NHstateArrest = requests.get(NHArrestUrl).json()
NJstateArrest = requests.get(NJArrestUrl).json()
NMstateArrest = requests.get(NMArrestUrl).json()
NVstateArrest = requests.get(NVArrestUrl).json()
NYstateArrest = requests.get(NYArrestUrl).json()
OHstateArrest = requests.get(OHArrestUrl).json()
OKstateArrest = requests.get(OKArrestUrl).json()
ORstateArrest = requests.get(ORArrestUrl).json()
PAstateArrest = requests.get(PAArrestUrl).json()
RIstateArrest = requests.get(RIArrestUrl).json()
SCstateArrest = requests.get(SCArrestUrl).json()
SDstateArrest = requests.get(SDArrestUrl).json()
TNstateArrest = requests.get(TNArrestUrl).json()
TXstateArrest = requests.get(TXArrestUrl).json()
UTstateArrest = requests.get(UTArrestUrl).json()
VAstateArrest = requests.get(VAArrestUrl).json()
VTstateArrest = requests.get(VTArrestUrl).json()
WAstateArrest = requests.get(WAArrestUrl).json()
WIstateArrest = requests.get(WIArrestUrl).json()
WVstateArrest = requests.get(WVArrestUrl).json()
WYstateArrest = requests.get(WYArrestUrl).json()
PRstateArrest = requests.get(PRArrestUrl).json()
MPstateArrest = requests.get(MPArrestUrl).json()
OTstateArrest = requests.get(OTArrestUrl).json()
VIstateArrest = requests.get(VIArrestUrl).json()
# Out:
# {'ui_type': 'basic_table',
#  'noun': 'Offense',
#  'category': 'Arrestee Offense',
#  'title': 'All Arrest by Offense',
#  'short_title': 'offense',
#  'ui_restriction': None,
#  'keys': ['Aggravated Assault',
#   'All Other Offenses (Except Traffic)',
#   'Arson',
#   'Burglary',
#   'Curfew and Loitering Law Violations',
#   'Disorderly Conduct',
#   'Driving Under the Influence',
#   'Drug Abuse Violations - Grand Total',
#   'Drunkenness',
#   'Embezzlement',
#   'Forgery and Counterfeiting',
#   'Fraud',
#   'Gambling - Total',
#   'Human Trafficking - Commercial Sex Acts',
#   'Human Trafficking - Involuntary Servitude',
#   'Larceny - Theft',
#   'Liquor Laws',
#   'Manslaughter by Negligence',
#   'Motor Vehicle Theft',
#   'Murder and Nonnegligent Manslaughter',
#   'Offenses Against the Family and Children',
#   'Prostitution and Commercialized Vice',
#   'Rape',
#   'Robbery',
#   'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)',
#   'Simple Assault',
#   'Stolen Property: Buying, Receiving, Possessing',
#   'Suspicion',
#   'Vagrancy',
#   'Vandalism',
#   'Weapons: Carrying, Possessing, Etc.'],
#  'data': [{'value': 2170,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 1949,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 2027,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 2115,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 1912,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3223,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3435,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3306,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3374,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3343,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3758,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3685,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 4318,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3747,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 5123,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3968,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3469,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3595,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3701,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 4340,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 4978,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 5482,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 2516,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3898,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3322,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3319,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3366,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3433,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3085,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3140,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3720,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3929,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 3851,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 4223,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Aggravated Assault'},
#   {'value': 23066,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 24497,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 25372,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 28804,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 34121,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 38481,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 43680,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 49235,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 52554,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 52520,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 64826,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 68585,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 73546,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 69187,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 91759,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 88075,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 73887,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 54187,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 61618,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 74008,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 76068,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 70664,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 44034,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 57722,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 64566,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 63786,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 59960,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 63424,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 65764,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 55480,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 60187,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 62562,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 55394,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 58859,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'All Other Offenses (Except Traffic)'},
#   {'value': 130, 'data_year': 1985, 'month_num': 0, 'key': 'Arson'},
#   {'value': 97, 'data_year': 1986, 'month_num': 0, 'key': 'Arson'},
#   {'value': 130, 'data_year': 1987, 'month_num': 0, 'key': 'Arson'},
#   {'value': 113, 'data_year': 1988, 'month_num': 0, 'key': 'Arson'},
#   {'value': 93, 'data_year': 1989, 'month_num': 0, 'key': 'Arson'},
#   {'value': 125, 'data_year': 1990, 'month_num': 0, 'key': 'Arson'},
#   {'value': 110, 'data_year': 1991, 'month_num': 0, 'key': 'Arson'},
#   {'value': 150, 'data_year': 1992, 'month_num': 0, 'key': 'Arson'},
#   {'value': 137, 'data_year': 1993, 'month_num': 0, 'key': 'Arson'},
#   {'value': 131, 'data_year': 1994, 'month_num': 0, 'key': 'Arson'},
#   {'value': 123, 'data_year': 1995, 'month_num': 0, 'key': 'Arson'},
#   {'value': 117, 'data_year': 1996, 'month_num': 0, 'key': 'Arson'},
#   {'value': 117, 'data_year': 1997, 'month_num': 0, 'key': 'Arson'},
#   {'value': 118, 'data_year': 1998, 'month_num': 0, 'key': 'Arson'},
#   {'value': 117, 'data_year': 1999, 'month_num': 0, 'key': 'Arson'},
#   {'value': 127, 'data_year': 2000, 'month_num': 0, 'key': 'Arson'},
#   {'value': 147, 'data_year': 2001, 'month_num': 0, 'key': 'Arson'},
#   {'value': 76, 'data_year': 2002, 'month_num': 0, 'key': 'Arson'},
#   {'value': 96, 'data_year': 2003, 'month_num': 0, 'key': 'Arson'},
#   {'value': 98, 'data_year': 2004, 'month_num': 0, 'key': 'Arson'},
#   {'value': 98, 'data_year': 2005, 'month_num': 0, 'key': 'Arson'},
#   {'value': 108, 'data_year': 2006, 'month_num': 0, 'key': 'Arson'},
#   {'value': 32, 'data_year': 2007, 'month_num': 0, 'key': 'Arson'},
#   {'value': 62, 'data_year': 2008, 'month_num': 0, 'key': 'Arson'},
#   {'value': 83, 'data_year': 2009, 'month_num': 0, 'key': 'Arson'},
#   {'value': 63, 'data_year': 2010, 'month_num': 0, 'key': 'Arson'},
#   {'value': 68, 'data_year': 2011, 'month_num': 0, 'key': 'Arson'},
#   {'value': 53, 'data_year': 2012, 'month_num': 0, 'key': 'Arson'},
#   {'value': 57, 'data_year': 2013, 'month_num': 0, 'key': 'Arson'},
#   {'value': 50, 'data_year': 2014, 'month_num': 0, 'key': 'Arson'},
#   {'value': 74, 'data_year': 2015, 'month_num': 0, 'key': 'Arson'},
#   {'value': 47, 'data_year': 2016, 'month_num': 0, 'key': 'Arson'},
#   {'value': 40, 'data_year': 2017, 'month_num': 0, 'key': 'Arson'},
#   {'value': 67, 'data_year': 2018, 'month_num': 0, 'key': 'Arson'},
#   {'value': 3598, 'data_year': 1985, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3413, 'data_year': 1986, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3358, 'data_year': 1987, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3287, 'data_year': 1988, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3278, 'data_year': 1989, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3378, 'data_year': 1990, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3596, 'data_year': 1991, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3609, 'data_year': 1992, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3387, 'data_year': 1993, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3393, 'data_year': 1994, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3430, 'data_year': 1995, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3243, 'data_year': 1996, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3189, 'data_year': 1997, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3279, 'data_year': 1998, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3551, 'data_year': 1999, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2971, 'data_year': 2000, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2041, 'data_year': 2001, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 1628, 'data_year': 2002, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2522, 'data_year': 2003, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2860, 'data_year': 2004, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2872, 'data_year': 2005, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3335, 'data_year': 2006, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2220, 'data_year': 2007, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 3088, 'data_year': 2008, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2967, 'data_year': 2009, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2676, 'data_year': 2010, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2910, 'data_year': 2011, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2901, 'data_year': 2012, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2766, 'data_year': 2013, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2197, 'data_year': 2014, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2033, 'data_year': 2015, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2237, 'data_year': 2016, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 2134, 'data_year': 2017, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 1997, 'data_year': 2018, 'month_num': 0, 'key': 'Burglary'},
#   {'value': 425,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 414,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 428,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 495,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 451,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 392,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 572,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 951,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 799,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1706,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1944,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1949,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 2450,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1695,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1545,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 2519,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1270,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1479,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 679,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 1244,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 901,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 915,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 530,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 773,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 809,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 861,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 561,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 296,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 243,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 204,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 313,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 365,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 312,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 273,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Curfew and Loitering Law Violations'},
#   {'value': 5115,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 5201,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 4825,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 4890,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 5323,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 6336,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 6908,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 6929,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 6812,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 7287,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 8144,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 8592,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 7943,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 8103,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 8257,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 6423,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 5145,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 4329,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3370,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3403,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3838,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 4181,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 2552,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3766,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3745,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3485,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3514,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3502,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 3308,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 2526,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 2392,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 2644,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 2541,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 2434,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Disorderly Conduct'},
#   {'value': 19525,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 20348,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 17454,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 16160,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 16375,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 19376,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 20594,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 20424,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 19567,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 18688,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 19742,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 18656,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 17253,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 17164,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 19287,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 18958,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 16620,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 12730,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 12192,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 11923,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 12172,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 12521,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 10075,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 12395,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 11748,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 10308,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 9775,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 9581,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 7880,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 7070,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 7128,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 6817,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 6076,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 6242,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Driving Under the Influence'},
#   {'value': 5910,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 5143,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 5664,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 5413,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 6256,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 5830,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 6290,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 7216,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 7931,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 9212,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 11206,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 11640,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 11857,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 13298,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 15560,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 13028,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 11500,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 9054,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 12047,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 12838,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 14848,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 15392,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 10698,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 12047,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 12312,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 12973,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 11067,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 11462,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 11477,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 11534,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 12901,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 16030,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 17868,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 19279,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Drug Abuse Violations - Grand Total'},
#   {'value': 20175, 'data_year': 1985, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 20107, 'data_year': 1986, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 17356, 'data_year': 1987, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 17274, 'data_year': 1988, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 16079, 'data_year': 1989, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 19484, 'data_year': 1990, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 22684, 'data_year': 1991, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 21478, 'data_year': 1992, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 21120, 'data_year': 1993, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 20570, 'data_year': 1994, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 20450, 'data_year': 1995, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 20413, 'data_year': 1996, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 16716, 'data_year': 1997, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 18076, 'data_year': 1998, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 18861, 'data_year': 1999, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 17170, 'data_year': 2000, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 15629, 'data_year': 2001, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 12236, 'data_year': 2002, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 11657, 'data_year': 2003, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 10237, 'data_year': 2004, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 9818, 'data_year': 2005, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 10937, 'data_year': 2006, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 8473, 'data_year': 2007, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 10596, 'data_year': 2008, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 9538, 'data_year': 2009, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 9541, 'data_year': 2010, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 9168, 'data_year': 2011, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 9627, 'data_year': 2012, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 8672, 'data_year': 2013, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 6017, 'data_year': 2014, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 7102, 'data_year': 2015, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 6901, 'data_year': 2016, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 6308, 'data_year': 2017, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 6331, 'data_year': 2018, 'month_num': 0, 'key': 'Drunkenness'},
#   {'value': 16, 'data_year': 1985, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 18, 'data_year': 1986, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 27, 'data_year': 1987, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 21, 'data_year': 1988, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 44, 'data_year': 1989, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 21, 'data_year': 1990, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 11, 'data_year': 1991, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 80, 'data_year': 1992, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 9, 'data_year': 1993, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 13, 'data_year': 1994, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 17, 'data_year': 1995, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 29, 'data_year': 1996, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 19, 'data_year': 1997, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 16, 'data_year': 1998, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 79, 'data_year': 1999, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 5, 'data_year': 2000, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 53, 'data_year': 2001, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 147, 'data_year': 2002, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 3, 'data_year': 2003, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 8, 'data_year': 2004, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 12, 'data_year': 2005, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 9, 'data_year': 2006, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 19, 'data_year': 2007, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 54, 'data_year': 2008, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 44, 'data_year': 2009, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 56, 'data_year': 2010, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 38, 'data_year': 2011, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 46, 'data_year': 2012, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 27, 'data_year': 2013, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 44, 'data_year': 2014, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 55, 'data_year': 2015, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 64, 'data_year': 2016, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 60, 'data_year': 2017, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 54, 'data_year': 2018, 'month_num': 0, 'key': 'Embezzlement'},
#   {'value': 1197,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 987,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1089,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1106,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1258,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1265,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1536,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1427,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1709,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1842,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 2337,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 2045,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1932,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 2226,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 2189,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 2188,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1818,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1493,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1951,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 2057,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 2271,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 1865,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 886,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 976,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 888,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 879,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 777,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 841,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 812,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 754,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 708,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 854,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 859,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 900,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Forgery and Counterfeiting'},
#   {'value': 9347, 'data_year': 1985, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 9634, 'data_year': 1986, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 9950, 'data_year': 1987, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 11070, 'data_year': 1988, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 14457, 'data_year': 1989, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 15352, 'data_year': 1990, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 18722, 'data_year': 1991, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 19523, 'data_year': 1992, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 20960, 'data_year': 1993, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 17555, 'data_year': 1994, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 17926, 'data_year': 1995, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 17949, 'data_year': 1996, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 14372, 'data_year': 1997, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 17646, 'data_year': 1998, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 26377, 'data_year': 1999, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 19538, 'data_year': 2000, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 19331, 'data_year': 2001, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 8851, 'data_year': 2002, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 13409, 'data_year': 2003, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 12438, 'data_year': 2004, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 13181, 'data_year': 2005, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 10634, 'data_year': 2006, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 7960, 'data_year': 2007, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 7910, 'data_year': 2008, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 6599, 'data_year': 2009, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 4125, 'data_year': 2010, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 2464, 'data_year': 2011, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 1932, 'data_year': 2012, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 1586, 'data_year': 2013, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 1288, 'data_year': 2014, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 1181, 'data_year': 2015, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 1134, 'data_year': 2016, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 915, 'data_year': 2017, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 958, 'data_year': 2018, 'month_num': 0, 'key': 'Fraud'},
#   {'value': 362, 'data_year': 1985, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 382, 'data_year': 1986, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 318, 'data_year': 1987, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 231, 'data_year': 1988, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 149, 'data_year': 1989, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 174, 'data_year': 1990, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 213, 'data_year': 1991, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 351, 'data_year': 1992, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 144, 'data_year': 1993, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 158, 'data_year': 1994, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 186, 'data_year': 1995, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 143, 'data_year': 1996, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 115, 'data_year': 1997, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 119, 'data_year': 1998, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 144, 'data_year': 1999, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 33, 'data_year': 2000, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 110, 'data_year': 2001, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 41, 'data_year': 2002, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 52, 'data_year': 2003, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 23, 'data_year': 2004, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 33, 'data_year': 2005, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 19, 'data_year': 2006, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 3, 'data_year': 2007, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 24, 'data_year': 2008, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 34, 'data_year': 2009, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 26, 'data_year': 2010, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 28, 'data_year': 2011, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 29, 'data_year': 2012, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 39, 'data_year': 2013, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 8, 'data_year': 2014, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 1, 'data_year': 2015, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 8, 'data_year': 2016, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 13, 'data_year': 2017, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 7, 'data_year': 2018, 'month_num': 0, 'key': 'Gambling - Total'},
#   {'value': 0,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Commercial Sex Acts'},
#   {'value': 0,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 0,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 1,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Human Trafficking - Involuntary Servitude'},
#   {'value': 11701,
#    'data_year': 1985,
# ...
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 535,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 733,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 824,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 724,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 559,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 517,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 454,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 373,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 401,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 337,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 161,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 200,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 196,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 205,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 184,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 198,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 162,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 125,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 138,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 124,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 68,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 104,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)'},
#   {'value': 4405, 'data_year': 1985, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 4338, 'data_year': 1986, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 4265, 'data_year': 1987, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 4103, 'data_year': 1988, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 5152, 'data_year': 1989, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 5301, 'data_year': 1990, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 6243, 'data_year': 1991, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 6758, 'data_year': 1992, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 7141, 'data_year': 1993, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 7587, 'data_year': 1994, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 8633, 'data_year': 1995, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 8351, 'data_year': 1996, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 7733, 'data_year': 1997, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 8428, 'data_year': 1998, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 8361, 'data_year': 1999, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 8179, 'data_year': 2000, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 6279, 'data_year': 2001, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 5305, 'data_year': 2002, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 6176, 'data_year': 2003, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 8538, 'data_year': 2004, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 10399, 'data_year': 2005, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 10256, 'data_year': 2006, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 8853, 'data_year': 2007, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 10031, 'data_year': 2008, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 11713, 'data_year': 2009, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 11684, 'data_year': 2010, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 11806, 'data_year': 2011, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 12285, 'data_year': 2012, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 11096, 'data_year': 2013, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 10806, 'data_year': 2014, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 11409, 'data_year': 2015, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 12257, 'data_year': 2016, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 11712, 'data_year': 2017, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 12595, 'data_year': 2018, 'month_num': 0, 'key': 'Simple Assault'},
#   {'value': 1467,
#    'data_year': 1985,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1211,
#    'data_year': 1986,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1450,
#    'data_year': 1987,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1609,
#    'data_year': 1988,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1536,
#    'data_year': 1989,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1982,
#    'data_year': 1990,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 2426,
#    'data_year': 1991,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 2548,
#    'data_year': 1992,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 2545,
#    'data_year': 1993,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 2385,
#    'data_year': 1994,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 2350,
#    'data_year': 1995,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 2286,
#    'data_year': 1996,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 2067,
#    'data_year': 1997,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1729,
#    'data_year': 1998,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1749,
#    'data_year': 1999,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1646,
#    'data_year': 2000,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1416,
#    'data_year': 2001,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1286,
#    'data_year': 2002,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1253,
#    'data_year': 2003,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1460,
#    'data_year': 2004,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1569,
#    'data_year': 2005,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1602,
#    'data_year': 2006,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 968,
#    'data_year': 2007,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1270,
#    'data_year': 2008,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1079,
#    'data_year': 2009,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1081,
#    'data_year': 2010,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1017,
#    'data_year': 2011,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1078,
#    'data_year': 2012,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1024,
#    'data_year': 2013,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1160,
#    'data_year': 2014,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1273,
#    'data_year': 2015,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1440,
#    'data_year': 2016,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1794,
#    'data_year': 2017,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 1876,
#    'data_year': 2018,
#    'month_num': 0,
#    'key': 'Stolen Property: Buying, Receiving, Possessing'},
#   {'value': 293, 'data_year': 1985, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 337, 'data_year': 1986, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 359, 'data_year': 1987, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 333, 'data_year': 1988, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 201, 'data_year': 1989, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 290, 'data_year': 1990, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 307, 'data_year': 1991, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 448, 'data_year': 1992, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 619, 'data_year': 1993, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 437, 'data_year': 1994, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 548, 'data_year': 1995, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 864, 'data_year': 1996, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1019, 'data_year': 1997, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 503, 'data_year': 1998, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 805, 'data_year': 1999, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 409, 'data_year': 2000, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 465, 'data_year': 2001, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1191, 'data_year': 2002, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 266, 'data_year': 2003, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 296, 'data_year': 2004, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 358, 'data_year': 2005, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 398, 'data_year': 2006, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 1, 'data_year': 2007, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 113, 'data_year': 2008, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2009, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2010, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2011, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2012, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2013, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2014, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2015, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2016, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2017, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 0, 'data_year': 2018, 'month_num': 0, 'key': 'Suspicion'},
#   {'value': 257, 'data_year': 1985, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 262, 'data_year': 1986, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 255, 'data_year': 1987, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 348, 'data_year': 1988, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 535, 'data_year': 1989, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 413, 'data_year': 1990, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 455, 'data_year': 1991, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 551, 'data_year': 1992, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 638, 'data_year': 1993, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 945, 'data_year': 1994, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1022, 'data_year': 1995, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1106, 'data_year': 1996, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 868, 'data_year': 1997, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1001, 'data_year': 1998, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1153, 'data_year': 1999, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1055, 'data_year': 2000, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1538, 'data_year': 2001, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 994, 'data_year': 2002, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1104, 'data_year': 2003, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1395, 'data_year': 2004, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1850, 'data_year': 2005, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 2282, 'data_year': 2006, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 679, 'data_year': 2007, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1224, 'data_year': 2008, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 720, 'data_year': 2009, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 677, 'data_year': 2010, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 610, 'data_year': 2011, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 525, 'data_year': 2012, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 565, 'data_year': 2013, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 544, 'data_year': 2014, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 741, 'data_year': 2015, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 894, 'data_year': 2016, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 320, 'data_year': 2017, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 350, 'data_year': 2018, 'month_num': 0, 'key': 'Vagrancy'},
#   {'value': 1056, 'data_year': 1985, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1154, 'data_year': 1986, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1111, 'data_year': 1987, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1129, 'data_year': 1988, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1110, 'data_year': 1989, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1368, 'data_year': 1990, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1616, 'data_year': 1991, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1648, 'data_year': 1992, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1479, 'data_year': 1993, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1271, 'data_year': 1994, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1338, 'data_year': 1995, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1304, 'data_year': 1996, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1219, 'data_year': 1997, 'month_num': 0, 'key': 'Vandalism'},
#   {'value': 1162, 'data_year': 1998, 'month_num': 0, 'key': 'Vandalism'},
#   ...],
#  'precise_data': []}

# %%
# State level UCR Police Employment data
AKPolEmployment = f"{FBIurl}api/police-employment/states/AK/1985/2018"
ALPolEmployment = f"{FBIurl}api/police-employment/states/AL/1985/2018"
ARPolEmployment = f"{FBIurl}api/police-employment/states/AR/1985/2018"
ASPolEmployment = f"{FBIurl}api/police-employment/states/AS/1985/2018"
AZPolEmployment = f"{FBIurl}api/police-employment/states/AZ/1985/2018"
CAPolEmployment = f"{FBIurl}api/police-employment/states/CA/1985/2018"
COPolEmployment = f"{FBIurl}api/police-employment/states/CO/1985/2018"
CTPolEmployment = f"{FBIurl}api/police-employment/states/CT/1985/2018"
CZPolEmployment = f"{FBIurl}api/police-employment/states/CZ/1985/2018"
DCPolEmployment = f"{FBIurl}api/police-employment/states/DC/1985/2018"
DEPolEmployment = f"{FBIurl}api/police-employment/states/DE/1985/2018"
FLPolEmployment = f"{FBIurl}api/police-employment/states/FL/1985/2018"
GAPolEmployment = f"{FBIurl}api/police-employment/states/GA/1985/2018"
GMPolEmployment = f"{FBIurl}api/police-employment/states/GM/1985/2018"
HIPolEmployment = f"{FBIurl}api/police-employment/states/HI/1985/2018"
IAPolEmployment = f"{FBIurl}api/police-employment/states/IA/1985/2018"
IDPolEmployment = f"{FBIurl}api/police-employment/states/ID/1985/2018"
ILPolEmployment = f"{FBIurl}api/police-employment/states/IL/1985/2018"
INPolEmployment = f"{FBIurl}api/police-employment/states/IN/1985/2018"
KSPolEmployment = f"{FBIurl}api/police-employment/states/KS/1985/2018"
KYPolEmployment = f"{FBIurl}api/police-employment/states/KY/1985/2018"
LAPolEmployment = f"{FBIurl}api/police-employment/states/LA/1985/2018"
MAPolEmployment = f"{FBIurl}api/police-employment/states/MA/1985/2018"
MDPolEmployment = f"{FBIurl}api/police-employment/states/MD/1985/2018"
MEPolEmployment = f"{FBIurl}api/police-employment/states/ME/1985/2018"
MIPolEmployment = f"{FBIurl}api/police-employment/states/MI/1985/2018"
MNPolEmployment = f"{FBIurl}api/police-employment/states/MN/1985/2018"
MOPolEmployment = f"{FBIurl}api/police-employment/states/MO/1985/2018"
MSPolEmployment = f"{FBIurl}api/police-employment/states/MS/1985/2018"
MTPolEmployment = f"{FBIurl}api/police-employment/states/MT/1985/2018"
NCPolEmployment = f"{FBIurl}api/police-employment/states/NC/1985/2018"
NDPolEmployment = f"{FBIurl}api/police-employment/states/ND/1985/2018"
NEPolEmployment = f"{FBIurl}api/police-employment/states/NE/1985/2018"
NHPolEmployment = f"{FBIurl}api/police-employment/states/NH/1985/2018"
NJPolEmployment = f"{FBIurl}api/police-employment/states/NJ/1985/2018"
NMPolEmployment = f"{FBIurl}api/police-employment/states/NM/1985/2018"
NVPolEmployment = f"{FBIurl}api/police-employment/states/NV/1985/2018"
NYPolEmployment = f"{FBIurl}api/police-employment/states/NY/1985/2018"
OHPolEmployment = f"{FBIurl}api/police-employment/states/OH/1985/2018"
OKPolEmployment = f"{FBIurl}api/police-employment/states/OK/1985/2018"
ORPolEmployment = f"{FBIurl}api/police-employment/states/OR/1985/2018"
PAPolEmployment = f"{FBIurl}api/police-employment/states/PA/1985/2018"
RIPolEmployment = f"{FBIurl}api/police-employment/states/RI/1985/2018"
SCPolEmployment = f"{FBIurl}api/police-employment/states/SC/1985/2018"
SDPolEmployment = f"{FBIurl}api/police-employment/states/SD/1985/2018"
TNPolEmployment = f"{FBIurl}api/police-employment/states/TN/1985/2018"
TXPolEmployment = f"{FBIurl}api/police-employment/states/TX/1985/2018"
UTPolEmployment = f"{FBIurl}api/police-employment/states/UT/1985/2018"
VAPolEmployment = f"{FBIurl}api/police-employment/states/VA/1985/2018"
VTPolEmployment = f"{FBIurl}api/police-employment/states/VT/1985/2018"
WAPolEmployment = f"{FBIurl}api/police-employment/states/WA/1985/2018"
WIPolEmployment = f"{FBIurl}api/police-employment/states/WI/1985/2018"
WVPolEmployment = f"{FBIurl}api/police-employment/states/WV/1985/2018"
WYPolEmployment = f"{FBIurl}api/police-employment/states/WY/1985/2018"
PRPolEmployment = f"{FBIurl}api/police-employment/states/PR/1985/2018"
MPPolEmployment = f"{FBIurl}api/police-employment/states/MP/1985/2018"
OTPolEmployment = f"{FBIurl}api/police-employment/states/OT/1985/2018"
VIPolEmployment = f"{FBIurl}api/police-employment/states/VI/1985/2018"
# Base Url
AKPolEmploymentUrl = f"{AKPolEmployment}?api_key={datagov_key}"
ALPolEmploymentUrl = f"{ALPolEmployment}?api_key={datagov_key}"
ARPolEmploymentUrl = f"{ARPolEmployment}?api_key={datagov_key}"
ASPolEmploymentUrl = f"{ASPolEmployment}?api_key={datagov_key}"
AZPolEmploymentUrl = f"{AZPolEmployment}?api_key={datagov_key}"
CAPolEmploymentUrl = f"{CAPolEmployment}?api_key={datagov_key}"
COPolEmploymentUrl = f"{COPolEmployment}?api_key={datagov_key}"
CTPolEmploymentUrl = f"{CTPolEmployment}?api_key={datagov_key}"
CZPolEmploymentUrl = f"{CZPolEmployment}?api_key={datagov_key}"
DCPolEmploymentUrl = f"{DCPolEmployment}?api_key={datagov_key}"
DEPolEmploymentUrl = f"{DEPolEmployment}?api_key={datagov_key}"
FLPolEmploymentUrl = f"{FLPolEmployment}?api_key={datagov_key}"
GAPolEmploymentUrl = f"{GAPolEmployment}?api_key={datagov_key}"
GMPolEmploymentUrl = f"{GMPolEmployment}?api_key={datagov_key}"
HIPolEmploymentUrl = f"{HIPolEmployment}?api_key={datagov_key}"
IAPolEmploymentUrl = f"{IAPolEmployment}?api_key={datagov_key}"
IDPolEmploymentUrl = f"{IDPolEmployment}?api_key={datagov_key}"
ILPolEmploymentUrl = f"{ILPolEmployment}?api_key={datagov_key}"
INPolEmploymentUrl = f"{INPolEmployment}?api_key={datagov_key}"
KSPolEmploymentUrl = f"{KSPolEmployment}?api_key={datagov_key}"
KYPolEmploymentUrl = f"{KYPolEmployment}?api_key={datagov_key}"
LAPolEmploymentUrl = f"{LAPolEmployment}?api_key={datagov_key}"
MAPolEmploymentUrl = f"{MAPolEmployment}?api_key={datagov_key}"
MDPolEmploymentUrl = f"{MDPolEmployment}?api_key={datagov_key}"
MEPolEmploymentUrl = f"{MEPolEmployment}?api_key={datagov_key}"
MIPolEmploymentUrl = f"{MIPolEmployment}?api_key={datagov_key}"
MNPolEmploymentUrl = f"{MNPolEmployment}?api_key={datagov_key}"
MOPolEmploymentUrl = f"{MOPolEmployment}?api_key={datagov_key}"
MSPolEmploymentUrl = f"{MSPolEmployment}?api_key={datagov_key}"
MTPolEmploymentUrl = f"{MTPolEmployment}?api_key={datagov_key}"
NCPolEmploymentUrl = f"{NCPolEmployment}?api_key={datagov_key}"
NDPolEmploymentUrl = f"{NDPolEmployment}?api_key={datagov_key}"
NEPolEmploymentUrl = f"{NEPolEmployment}?api_key={datagov_key}"
NHPolEmploymentUrl = f"{NHPolEmployment}?api_key={datagov_key}"
NJPolEmploymentUrl = f"{NJPolEmployment}?api_key={datagov_key}"
NMPolEmploymentUrl = f"{NMPolEmployment}?api_key={datagov_key}"
NVPolEmploymentUrl = f"{NVPolEmployment}?api_key={datagov_key}"
NYPolEmploymentUrl = f"{NYPolEmployment}?api_key={datagov_key}"
OHPolEmploymentUrl = f"{OHPolEmployment}?api_key={datagov_key}"
OKPolEmploymentUrl = f"{OKPolEmployment}?api_key={datagov_key}"
ORPolEmploymentUrl = f"{ORPolEmployment}?api_key={datagov_key}"
PAPolEmploymentUrl = f"{PAPolEmployment}?api_key={datagov_key}"
RIPolEmploymentUrl = f"{RIPolEmployment}?api_key={datagov_key}"
SCPolEmploymentUrl = f"{SCPolEmployment}?api_key={datagov_key}"
SDPolEmploymentUrl = f"{SDPolEmployment}?api_key={datagov_key}"
TNPolEmploymentUrl = f"{TNPolEmployment}?api_key={datagov_key}"
TXPolEmploymentUrl = f"{TXPolEmployment}?api_key={datagov_key}"
UTPolEmploymentUrl = f"{UTPolEmployment}?api_key={datagov_key}"
VAPolEmploymentUrl = f"{VAPolEmployment}?api_key={datagov_key}"
VTPolEmploymentUrl = f"{VTPolEmployment}?api_key={datagov_key}"
WAPolEmploymentUrl = f"{WAPolEmployment}?api_key={datagov_key}"
WIPolEmploymentUrl = f"{WIPolEmployment}?api_key={datagov_key}"
WVPolEmploymentUrl = f"{WVPolEmployment}?api_key={datagov_key}"
WYPolEmploymentUrl = f"{WYPolEmployment}?api_key={datagov_key}"
PRPolEmploymentUrl = f"{PRPolEmployment}?api_key={datagov_key}"
MPPolEmploymentUrl = f"{MPPolEmployment}?api_key={datagov_key}"
OTPolEmploymentUrl = f"{OTPolEmployment}?api_key={datagov_key}"
VIPolEmploymentUrl = f"{VIPolEmployment}?api_key={datagov_key}"
# Retrieve data and convert to json
AKstatePolEmployment = requests.get(AKPolEmploymentUrl).json()
ALstatePolEmployment = requests.get(ALPolEmploymentUrl).json()
ARstatePolEmployment = requests.get(ARPolEmploymentUrl).json()
ASstatePolEmployment = requests.get(ASPolEmploymentUrl).json()
AZstatePolEmployment = requests.get(AZPolEmploymentUrl).json()
CAstatePolEmployment = requests.get(CAPolEmploymentUrl).json()
COstatePolEmployment = requests.get(COPolEmploymentUrl).json()
CTstatePolEmployment = requests.get(CTPolEmploymentUrl).json()
CZstatePolEmployment = requests.get(CZPolEmploymentUrl).json()
DCstatePolEmployment = requests.get(DCPolEmploymentUrl).json()
DEstatePolEmployment = requests.get(DEPolEmploymentUrl).json()
FLstatePolEmployment = requests.get(FLPolEmploymentUrl).json()
GAstatePolEmployment = requests.get(GAPolEmploymentUrl).json()
GMstatePolEmployment = requests.get(GMPolEmploymentUrl).json()
HIstatePolEmployment = requests.get(HIPolEmploymentUrl).json()
IAstatePolEmployment = requests.get(IAPolEmploymentUrl).json()
IDstatePolEmployment = requests.get(IDPolEmploymentUrl).json()
ILstatePolEmployment = requests.get(ILPolEmploymentUrl).json()
INstatePolEmployment = requests.get(INPolEmploymentUrl).json()
KSstatePolEmployment = requests.get(KSPolEmploymentUrl).json()
KYstatePolEmployment = requests.get(KYPolEmploymentUrl).json()
LAstatePolEmployment = requests.get(LAPolEmploymentUrl).json()
MAstatePolEmployment = requests.get(MAPolEmploymentUrl).json()
MDstatePolEmployment = requests.get(MDPolEmploymentUrl).json()
MEstatePolEmployment = requests.get(MEPolEmploymentUrl).json()
MIstatePolEmployment = requests.get(MIPolEmploymentUrl).json()
MNstatePolEmployment = requests.get(MNPolEmploymentUrl).json()
MOstatePolEmployment = requests.get(MOPolEmploymentUrl).json()
MSstatePolEmployment = requests.get(MSPolEmploymentUrl).json()
MTstatePolEmployment = requests.get(MTPolEmploymentUrl).json()
NCstatePolEmployment = requests.get(NCPolEmploymentUrl).json()
NDstatePolEmployment = requests.get(NDPolEmploymentUrl).json()
NEstatePolEmployment = requests.get(NEPolEmploymentUrl).json()
NHstatePolEmployment = requests.get(NHPolEmploymentUrl).json()
NJstatePolEmployment = requests.get(NJPolEmploymentUrl).json()
NMstatePolEmployment = requests.get(NMPolEmploymentUrl).json()
NVstatePolEmployment = requests.get(NVPolEmploymentUrl).json()
NYstatePolEmployment = requests.get(NYPolEmploymentUrl).json()
OHstatePolEmployment = requests.get(OHPolEmploymentUrl).json()
OKstatePolEmployment = requests.get(OKPolEmploymentUrl).json()
ORstatePolEmployment = requests.get(ORPolEmploymentUrl).json()
PAstatePolEmployment = requests.get(PAPolEmploymentUrl).json()
RIstatePolEmployment = requests.get(RIPolEmploymentUrl).json()
SCstatePolEmployment = requests.get(SCPolEmploymentUrl).json()
SDstatePolEmployment = requests.get(SDPolEmploymentUrl).json()
TNstatePolEmployment = requests.get(TNPolEmploymentUrl).json()
TXstatePolEmployment = requests.get(TXPolEmploymentUrl).json()
UTstatePolEmployment = requests.get(UTPolEmploymentUrl).json()
VAstatePolEmployment = requests.get(VAPolEmploymentUrl).json()
VTstatePolEmployment = requests.get(VTPolEmploymentUrl).json()
WAstatePolEmployment = requests.get(WAPolEmploymentUrl).json()
WIstatePolEmployment = requests.get(WIPolEmploymentUrl).json()
WVstatePolEmployment = requests.get(WVPolEmploymentUrl).json()
WYstatePolEmployment = requests.get(WYPolEmploymentUrl).json()
PRstatePolEmployment = requests.get(PRPolEmploymentUrl).json()
MPstatePolEmployment = requests.get(MPPolEmploymentUrl).json()
OTstatePolEmployment = requests.get(OTPolEmploymentUrl).json()
VIstatePolEmployment = requests.get(VIPolEmploymentUrl).json()
# Out:
# {'results': [{'data_year': 1985,
#    'civilian_ct': 490,
#    'female_civilian_ct': 369,
#    'female_officer_ct': 65,
#    'female_total_ct': 434,
#    'male_civilian_ct': 121,
#    'male_officer_ct': 976,
#    'male_total_ct': 1097,
#    'population': 579424,
#    'total_pe_ct': 1531,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 24,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.64},
#   {'data_year': 1986,
#    'civilian_ct': 734,
#    'female_civilian_ct': 436,
#    'female_officer_ct': 74,
#    'female_total_ct': 510,
#    'male_civilian_ct': 298,
#    'male_officer_ct': 957,
#    'male_total_ct': 1255,
#    'population': 534000,
#    'total_pe_ct': 1765,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 26,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.31},
#   {'data_year': 1987,
#    'civilian_ct': 531,
#    'female_civilian_ct': 349,
#    'female_officer_ct': 66,
#    'female_total_ct': 415,
#    'male_civilian_ct': 182,
#    'male_officer_ct': 898,
#    'male_total_ct': 1080,
#    'population': 525000,
#    'total_pe_ct': 1495,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 26,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.85},
#   {'data_year': 1988,
#    'civilian_ct': 583,
#    'female_civilian_ct': 401,
#    'female_officer_ct': 59,
#    'female_total_ct': 460,
#    'male_civilian_ct': 182,
#    'male_officer_ct': 898,
#    'male_total_ct': 1080,
#    'population': 513000,
#    'total_pe_ct': 1540,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 27,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.0},
#   {'data_year': 1989,
#    'civilian_ct': 536,
#    'female_civilian_ct': 386,
#    'female_officer_ct': 55,
#    'female_total_ct': 441,
#    'male_civilian_ct': 150,
#    'male_officer_ct': 889,
#    'male_total_ct': 1039,
#    'population': 527000,
#    'total_pe_ct': 1480,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 24,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.81},
#   {'data_year': 1990,
#    'civilian_ct': 516,
#    'female_civilian_ct': 397,
#    'female_officer_ct': 72,
#    'female_total_ct': 469,
#    'male_civilian_ct': 119,
#    'male_officer_ct': 916,
#    'male_total_ct': 1035,
#    'population': 550043,
#    'total_pe_ct': 1504,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 28,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.73},
#   {'data_year': 1991,
#    'civilian_ct': 614,
#    'female_civilian_ct': 450,
#    'female_officer_ct': 70,
#    'female_total_ct': 520,
#    'male_civilian_ct': 164,
#    'male_officer_ct': 964,
#    'male_total_ct': 1128,
#    'population': 570000,
#    'total_pe_ct': 1648,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 27,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.89},
#   {'data_year': 1992,
#    'civilian_ct': 552,
#    'female_civilian_ct': 431,
#    'female_officer_ct': 70,
#    'female_total_ct': 501,
#    'male_civilian_ct': 121,
#    'male_officer_ct': 954,
#    'male_total_ct': 1075,
#    'population': 587000,
#    'total_pe_ct': 1576,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 29,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.68},
#   {'data_year': 1993,
#    'civilian_ct': 615,
#    'female_civilian_ct': 448,
#    'female_officer_ct': 72,
#    'female_total_ct': 520,
#    'male_civilian_ct': 167,
#    'male_officer_ct': 1010,
#    'male_total_ct': 1177,
#    'population': 599000,
#    'total_pe_ct': 1697,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 28,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.83},
#   {'data_year': 1994,
#    'civilian_ct': 578,
#    'female_civilian_ct': 439,
#    'female_officer_ct': 75,
#    'female_total_ct': 514,
#    'male_civilian_ct': 139,
#    'male_officer_ct': 998,
#    'male_total_ct': 1137,
#    'population': 606000,
#    'total_pe_ct': 1651,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 28,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.72},
#   {'data_year': 1995,
#    'civilian_ct': 637,
#    'female_civilian_ct': 457,
#    'female_officer_ct': 83,
#    'female_total_ct': 540,
#    'male_civilian_ct': 180,
#    'male_officer_ct': 1051,
#    'male_total_ct': 1231,
#    'population': 604000,
#    'total_pe_ct': 1771,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 26,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.93},
#   {'data_year': 1996,
#    'civilian_ct': 653,
#    'female_civilian_ct': 475,
#    'female_officer_ct': 84,
#    'female_total_ct': 559,
#    'male_civilian_ct': 178,
#    'male_officer_ct': 1072,
#    'male_total_ct': 1250,
#    'population': 607000,
#    'total_pe_ct': 1809,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 28,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.98},
#   {'data_year': 1997,
#    'civilian_ct': 444,
#    'female_civilian_ct': 334,
#    'female_officer_ct': 76,
#    'female_total_ct': 410,
#    'male_civilian_ct': 110,
#    'male_officer_ct': 781,
#    'male_total_ct': 891,
#    'population': 609000,
#    'total_pe_ct': 1301,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 24,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.14},
#   {'data_year': 1998,
#    'civilian_ct': 659,
#    'female_civilian_ct': 457,
#    'female_officer_ct': 94,
#    'female_total_ct': 551,
#    'male_civilian_ct': 202,
#    'male_officer_ct': 1019,
#    'male_total_ct': 1221,
#    'population': 614000,
#    'total_pe_ct': 1772,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 26,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.89},
#   {'data_year': 1999,
#    'civilian_ct': 688,
#    'female_civilian_ct': 495,
#    'female_officer_ct': 103,
#    'female_total_ct': 598,
#    'male_civilian_ct': 193,
#    'male_officer_ct': 1066,
#    'male_total_ct': 1259,
#    'population': 619000,
#    'total_pe_ct': 1857,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 28,
#    'csv_header': None,
#    'pe_ct_per_1000': 3.0},
#   {'data_year': 2000,
#    'civilian_ct': 675,
#    'female_civilian_ct': 475,
#    'female_officer_ct': 103,
#    'female_total_ct': 578,
#    'male_civilian_ct': 200,
#    'male_officer_ct': 1055,
#    'male_total_ct': 1255,
#    'population': 626932,
#    'total_pe_ct': 1833,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 32,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.92},
#   {'data_year': 2001,
#    'civilian_ct': 661,
#    'female_civilian_ct': 463,
#    'female_officer_ct': 107,
#    'female_total_ct': 570,
#    'male_civilian_ct': 198,
#    'male_officer_ct': 1097,
#    'male_total_ct': 1295,
#    'population': 634892,
#    'total_pe_ct': 1865,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 33,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.94},
#   {'data_year': 2002,
#    'civilian_ct': 701,
#    'female_civilian_ct': 482,
#    'female_officer_ct': 112,
#    'female_total_ct': 594,
#    'male_civilian_ct': 219,
#    'male_officer_ct': 1091,
#    'male_total_ct': 1310,
#    'population': 643893,
#    'total_pe_ct': 1904,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 33,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.96},
#   {'data_year': 2003,
#    'civilian_ct': 682,
#    'female_civilian_ct': 470,
#    'female_officer_ct': 111,
#    'female_total_ct': 581,
#    'male_civilian_ct': 212,
#    'male_officer_ct': 1063,
#    'male_total_ct': 1275,
#    'population': 648921,
#    'total_pe_ct': 1856,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 33,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.86},
#   {'data_year': 2004,
#    'civilian_ct': 688,
#    'female_civilian_ct': 470,
#    'female_officer_ct': 127,
#    'female_total_ct': 597,
#    'male_civilian_ct': 218,
#    'male_officer_ct': 1125,
#    'male_total_ct': 1343,
#    'population': 655932,
#    'total_pe_ct': 1940,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 34,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.96},
#   {'data_year': 2005,
#    'civilian_ct': 669,
#    'female_civilian_ct': 468,
#    'female_officer_ct': 119,
#    'female_total_ct': 587,
#    'male_civilian_ct': 201,
#    'male_officer_ct': 1097,
#    'male_total_ct': 1298,
#    'population': 664150,
#    'total_pe_ct': 1885,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 33,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.84},
#   {'data_year': 2006,
#    'civilian_ct': 722,
#    'female_civilian_ct': 485,
#    'female_officer_ct': 126,
#    'female_total_ct': 611,
#    'male_civilian_ct': 237,
#    'male_officer_ct': 1133,
#    'male_total_ct': 1370,
#    'population': 670527,
#    'total_pe_ct': 1981,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 35,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.95},
#   {'data_year': 2007,
#    'civilian_ct': 689,
#    'female_civilian_ct': 454,
#    'female_officer_ct': 119,
#    'female_total_ct': 573,
#    'male_civilian_ct': 235,
#    'male_officer_ct': 1127,
#    'male_total_ct': 1362,
#    'population': 683918,
#    'total_pe_ct': 1935,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 35,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.83},
#   {'data_year': 2008,
#    'civilian_ct': 708,
#    'female_civilian_ct': 474,
#    'female_officer_ct': 119,
#    'female_total_ct': 593,
#    'male_civilian_ct': 234,
#    'male_officer_ct': 1180,
#    'male_total_ct': 1414,
#    'population': 686732,
#    'total_pe_ct': 2007,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 36,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.92},
#   {'data_year': 2009,
#    'civilian_ct': 720,
#    'female_civilian_ct': 474,
#    'female_officer_ct': 109,
#    'female_total_ct': 583,
#    'male_civilian_ct': 246,
#    'male_officer_ct': 1195,
#    'male_total_ct': 1441,
#    'population': 698901,
#    'total_pe_ct': 2024,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 36,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.9},
#   {'data_year': 2010,
#    'civilian_ct': 730,
#    'female_civilian_ct': 474,
#    'female_officer_ct': 106,
#    'female_total_ct': 580,
#    'male_civilian_ct': 256,
#    'male_officer_ct': 1152,
#    'male_total_ct': 1408,
#    'population': 711456,
#    'total_pe_ct': 1988,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 36,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.79},
#   {'data_year': 2011,
#    'civilian_ct': 710,
#    'female_civilian_ct': 472,
#    'female_officer_ct': 109,
#    'female_total_ct': 581,
#    'male_civilian_ct': 238,
#    'male_officer_ct': 1215,
#    'male_total_ct': 1453,
#    'population': 725910,
#    'total_pe_ct': 2034,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 35,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.8},
#   {'data_year': 2012,
#    'civilian_ct': 690,
#    'female_civilian_ct': 453,
#    'female_officer_ct': 109,
#    'female_total_ct': 562,
#    'male_civilian_ct': 237,
#    'male_officer_ct': 1221,
#    'male_total_ct': 1458,
#    'population': 735190,
#    'total_pe_ct': 2020,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 35,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.75},
#   {'data_year': 2013,
#    'civilian_ct': 634,
#    'female_civilian_ct': 443,
#    'female_officer_ct': 113,
#    'female_total_ct': 556,
#    'male_civilian_ct': 191,
#    'male_officer_ct': 1248,
#    'male_total_ct': 1439,
#    'population': 739005,
#    'total_pe_ct': 1995,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 33,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.7},
#   {'data_year': 2014,
#    'civilian_ct': 691,
#    'female_civilian_ct': 456,
#    'female_officer_ct': 116,
#    'female_total_ct': 572,
#    'male_civilian_ct': 235,
#    'male_officer_ct': 1202,
#    'male_total_ct': 1437,
#    'population': 740644,
#    'total_pe_ct': 2009,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 33,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.71},
#   {'data_year': 2015,
#    'civilian_ct': 691,
#    'female_civilian_ct': 456,
#    'female_officer_ct': 116,
#    'female_total_ct': 572,
#    'male_civilian_ct': 235,
#    'male_officer_ct': 1200,
#    'male_total_ct': 1435,
#    'population': 743350,
#    'total_pe_ct': 2007,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 32,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.7},
#   {'data_year': 2016,
#    'civilian_ct': 728,
#    'female_civilian_ct': 472,
#    'female_officer_ct': 113,
#    'female_total_ct': 585,
#    'male_civilian_ct': 256,
#    'male_officer_ct': 1156,
#    'male_total_ct': 1412,
#    'population': 747188,
#    'total_pe_ct': 1997,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 32,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.67},
#   {'data_year': 2017,
#    'civilian_ct': 686,
#    'female_civilian_ct': 437,
#    'female_officer_ct': 112,
#    'female_total_ct': 549,
#    'male_civilian_ct': 249,
#    'male_officer_ct': 1135,
#    'male_total_ct': 1384,
#    'population': 744849,
#    'total_pe_ct': 1933,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 32,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.6},
#   {'data_year': 2018,
#    'civilian_ct': 699,
#    'female_civilian_ct': 436,
#    'female_officer_ct': 124,
#    'female_total_ct': 560,
#    'male_civilian_ct': 263,
#    'male_officer_ct': 1162,
#    'male_total_ct': 1425,
#    'population': 742552,
#    'total_pe_ct': 1985,
#    'state_id': 1,
#    'state_name': 'Alaska',
#    'state_abbr': 'AK',
#    'agency_count_pe_submitting': 33,
#    'csv_header': None,
#    'pe_ct_per_1000': 2.67}],
#  'pagination': {'count': 34, 'page': 0, 'pages': 1, 'per_page': 0}}

# %%
# Concatenate State Crime data

# %%
# Concatenate State Arrest data

# %%
# Concatenate State Employment data
